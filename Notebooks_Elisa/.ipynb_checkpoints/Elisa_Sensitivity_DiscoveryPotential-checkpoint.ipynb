# %%
from __future__ import print_function
from csky.ipyconfig import *
from csky import bk, analysis, coord, dists, hyp, inj, llh, pdf, selections, trial, utils
import csky as cy
import histlite as hl
import healpy as hp
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
#from icecube import astro

mp_cpus = 15

# %%
ana_dir = utils.ensure_dir ('/data/user/drysewyk/csky_cache/ana_new')
repo = selections.mrichman_repo

# %%
ana7 = analysis.Analysis (repo, selections.PSDataSpecs.ps_7yr, dir=ana_dir)
# Out:
# Setting up Analysis for:
# IC40, IC59, IC79, IC86_2011, IC86_2012_2014
# Setting up IC40...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC40_MC.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC40_exp.npy ...
# <- /data/user/drysewyk/csky_cache/ana_new/IC40.subanalysis.npy
# Setting up IC59...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC59_MC.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC59_exp.npy ...
# <- /data/user/drysewyk/csky_cache/ana_new/IC59.subanalysis.npy
# Setting up IC79...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC79_MC.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC79_exp.npy ...
# <- /data/user/drysewyk/csky_cache/ana_new/IC79.subanalysis.npy
# Setting up IC86_2011...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC86_2011_MC.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC86_2011_exp.npy ...
# <- /data/user/drysewyk/csky_cache/ana_new/IC86_2011.subanalysis.npy
# Setting up IC86_2012_2014...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC86_2012_MC.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC86_2012_exp.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC86_2013_exp.npy ...
# Reading /data/user/mrichman/data/analyses/ps_tracks/current/IC86_2014_exp.npy ...
# <- /data/user/drysewyk/csky_cache/ana_new/IC86_2012_2014.subanalysis.npy
# Done.

# %%
# def get_llh (a, src, sigsub):
#     # space PDF - use default background space PDF and signal acceptance parameterization
#     space_model = pdf.PointSourceSpacePDFRatioModel ( a, src, a.bg_space_param, a.acc_param, sigsub=sigsub )
#     # energy PDF - use default parameterization
#     energy_model = a.energy_pdf_ratio_model
#     # put it together
#     pdf_ratio_model = pdf.MultiPDFRatioModel (space_model, energy_model)
#     N = len (a.data)
#     llh_model = llh.LLHModel (pdf_ratio_model, N, sigsub=sigsub)
#     return llh_model

# def get_injs (a, llh_model, src, flux, cut_n_sigma, inj):
#     # note which event features we need
#     keep = llh_model.pdf_ratio_model.keep
#     # optimization: dec band cut
#     selector = cy.inj.DecBandSelector (src, cut_n_sigma=cut_n_sigma)
#     # truth: unscrambled data, for unblinding
#     truth = cy.inj.DataInjector (a, selector (a.data), keep, randomizers=[])
#     # bg: scrambled data
#     randomizers = [cy.inj.RARandomizer ()]#, cy.inj.DecRandomizer()]#, cy.inj.PoleRandomizer (np.radians (30))]
#     bg = cy.inj.DataInjector (a, selector (a.data), keep, randomizers=randomizers)
#     # sig: signal injection
#     sig = cy.inj.PointSourceInjector (a, src, flux, keep) if inj else None
#     return truth, bg, sig

# def get_tr (src, ana=ana7, flux=hyp.PowerLawFlux (2), inj=True, use_energy=True, cut_n_sigma=5, sigsub=False, _fit_null=True, mp_cpus=mp_cpus):
#     # get_llh needs the src list
#     llh_kw = dict (src=src, sigsub=sigsub)
#     # get_injs needs the src list and signal spectrum
#     inj_kw = dict (src=src, flux=flux, cut_n_sigma=cut_n_sigma, inj=inj)
#     # trial.get_trial_runner loops over sub analyses and gives a single TrialRunner
#     return trial.get_trial_runner (
#         ana, get_llh, get_injs, llh_kw=llh_kw, inj_kw=inj_kw, mp_cpus=mp_cpus)


# def get_getters (ana=ana7, extension=0, cut_n_sigma=3, sigsub=False):
#     def get_tr_skymap (src=None, cut_n_sigma=3, _fit_null=True, inj=True):
#         if src is None:
#             src = utils.Sources (ra=0, dec=0, extension=extension)
#         src['extension'] = extension * np.ones_like (src.dec)
#         return get_tr (src, ana=ana, cut_n_sigma=cut_n_sigma, sigsub=sigsub, _fit_null=_fit_null, inj=inj)
#     def get_selector (dec):
#         return inj.DecBandSelector (utils.Sources (dec=dec, extension=extension))
#     return get_tr_skymap, get_selector

# def plot_result (v, clabel, title='', vmin=None, vmax=None, cmap='viridis', projection='aitoff'):
#     if vmin is None:
#         vmin = 0
#     if vmax is None:
#         vmax = np.ceil (v.max())
#     fig, ax = plt.subplots (figsize=(8,6), subplot_kw=dict (projection=projection))
#     sp = csp.SkyPlotter (pc_kw=dict (cmap=cmap, vmin=vmin, vmax=vmax))
#     v = hp.ud_grade (v, 256)
#     mesh, cb = sp.plot_map (ax, v, n_ticks=2, titleticks=bool (title))
#     sp.plot_gp (ax, color='.5', lw=.5, alpha=.25)
#     ax.grid (alpha=.5, ls='-')
#     cb.set_label (clabel)
#     ax.set_title (title)
#     plt.tight_layout()
#     return fig, ax

# def get_sens(ana,ra,sindec,ext,gamma,batch_size=500):
#     src = cy.utils.Sources(ra=0, dec=np.arcsin(sindec),extension=np.radians(ext))
#     #flux = hyp.PowerLawFlux(gamma)
#     tr = get_tr(src, ana)#, flux=flux)
#     bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
#     sens = tr.find_n_sig(bg.median(),0.9,batch_size=batch_size,max_batch_size=1000,tol=0.03) 
#     sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
#     return sens['flux']

# def get_sens_sigsub(ana,ra,sindec,ext,gamma,batch_size=500):
#     src = cy.utils.Sources(ra=0, dec=np.arcsin(sindec),extension=np.radians(ext))
#     #flux = hyp.PowerLawFlux(gamma)
#     tr = get_tr(src, ana, sigsub=True)#, flux=flux)
#     bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
#     sens = tr.find_n_sig(bg.median(),0.9,batch_size=batch_size,max_batch_size=1000,tol=0.03) 
#     sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
#     return sens['flux']

# def get_discovery(ana,ra,sindec,ext,gamma,batch_size=500):
#     src = utils.Sources(ra=0, dec=np.arcsin(sindec),extension=np.radians(ext))
#     #flux = hyp.PowerLawFlux(gamma)
#     tr = get_tr(src, ana)#, flux=flux)
#     bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
#     sens = tr.find_n_sig(bg.isf_nsigma(5,fit=True),0.5,batch_size=batch_size,max_batch_size=1000,tol=0.03) 
#     sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
#     return sens['flux']

# def get_discovery_sigsub(ana,ra,sindec,ext,gamma,batch_size=500):
#     src = utils.Sources(ra=0, dec=np.arcsin(sindec),extension=np.radians(ext))
#     #flux = hyp.PowerLawFlux(gamma)
#     tr = get_tr(src, ana, sigsub=True)#, flux=flux)
#     bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
#     sens = tr.find_n_sig(bg.isf_nsigma(5,fit=True),0.5,batch_size=batch_size,max_batch_size=1000,tol=0.03) 
#     sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
#     return sens['flux']

# %%
def get_llh (a, src, cut_n_sigma, sigsub):
    # space PDF - use default background space PDF and signal acceptance parameterization
    space_model = pdf.PointSourceSpacePDFRatioModel ( a, src, a.bg_space_param, a.acc_param, cut_n_sigma=cut_n_sigma, sigsub=sigsub )
    # energy PDF - use default parameterization
    energy_model = a.energy_pdf_ratio_model
    # put it together
    pdf_ratio_model = pdf.MultiPDFRatioModel (space_model, energy_model)
    N = len (a.data)
    llh_model = llh.LLHModel (pdf_ratio_model, N, cut_n_sigma=cut_n_sigma, sigsub=sigsub)
    return llh_model

def get_injs (a, llh_model, src, llh_src, flux, cut_n_sigma, inj):
    # note which event features we need
    keep = llh_model.pdf_ratio_model.keep
    # optimization: dec band cut
    selector = cy.inj.DecBandSelector (llh_src, cut_n_sigma=cut_n_sigma)
    # truth: unscrambled data, for unblinding
    truth = cy.inj.DataInjector (a, selector (a.data), keep, randomizers=[])
    # bg: scrambled data
    randomizers = [cy.inj.RARandomizer ()]#, cy.inj.DecRandomizer()]#, cy.inj.PoleRandomizer (np.radians (30))]
    bg = cy.inj.DataInjector (a, selector (a.data), keep, randomizers=randomizers)
    # sig: signal injection
    sig = cy.inj.PointSourceInjector (a, src, flux, keep) if inj else None
    return truth, bg, sig

def get_tr (src, ana=ana7, ext=np.radians(0), llh_ext=None, flux=hyp.PowerLawFlux (2), inj=True, use_energy=True, cut_n_sigma=None, sigsub=False, _fit_null=\
True, mp_cpus=mp_cpus):
    llh_ext = ext if llh_ext is None else llh_ext
    llh_src = cy.utils.Sources(ra=src.ra, dec=src.dec, extension=llh_ext)

    if cut_n_sigma is None:
        cut_n_sigma = 5 if llh_ext < np.radians(3) else 3

    # get_llh needs the src list
    llh_kw = dict (src=llh_src, cut_n_sigma=cut_n_sigma, sigsub=sigsub)
    # get_injs needs the src list and signal spectrum
    inj_kw = dict (src=src, llh_src=llh_src, flux=flux, cut_n_sigma=cut_n_sigma, inj=inj)
    # trial.get_trial_runner loops over sub analyses and gives a single TrialRunner
    return trial.get_trial_runner (
        ana, get_llh, get_injs, llh_kw=llh_kw, inj_kw=inj_kw, mp_cpus=mp_cpus)

def get_sens(ana, ra, sindec, ext=np.radians(0), llh_ext=None, cut_n_sigma=None, sigsub=False, gamma=2, batch_size=500):
    src = cy.utils.Sources(ra=0, dec=np.arcsin(sindec),extension=ext)
    flux = hyp.PowerLawFlux(gamma)
    tr = get_tr(src=src, ana=ana, ext=ext, llh_ext=llh_ext, flux=flux, cut_n_sigma=cut_n_sigma, sigsub=sigsub)
    bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
    sens = tr.find_n_sig(bg.median(),0.9,batch_size=batch_size,max_batch_size=1000,tol=0.03, coverage=2)
    sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
    return sens['flux']

def get_disc(ana, ra, sindec, ext=np.radians(0), llh_ext=None, cut_n_sigma=None, sigsub=False, gamma=2, batch_size=500):
    src = cy.utils.Sources(ra=0, dec=np.arcsin(sindec),extension=ext)
    flux = hyp.PowerLawFlux(gamma)
    tr = get_tr(src=src, ana=ana, ext=ext, llh_ext=llh_ext, flux=flux, cut_n_sigma=cut_n_sigma, sigsub=sigsub)
    bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
    sens = tr.find_n_sig(bg.isf_nsigma(5,fit=True),0.5,batch_size=batch_size,max_batch_size=1000,tol=0.03, coverage=2)
    sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
    return sens['flux']

# %%
sindec16 = np.sin(np.radians(16))

disc_0_llhextNone = get_disc(ana7,ra=0,sindec=np.sin(np.radians(16)),ext=np.radians(0),llh_ext=None, cut_n_sigma=None, gamma=2, sigsub=False)
disc_0_llhext0 = get_disc(ana7,ra=0,sindec=np.sin(np.radians(16)),ext=np.radians(0),llh_ext=np.radians(0), cut_n_sigma=None, gamma=2, sigsub=False)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 10:53:21.921310
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 33.474...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.02000
#   n_sig = 12.000 ... frac = 0.04000
#   n_sig = 15.000 ... frac = 0.24000
#   n_sig = 18.000 ... frac = 0.24000
#   n_sig = 21.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    8.40   16.80   25.20   33.60   42.00  | n_sig (relative error)
# 500      |          0.0%    5.2%   32.6%   69.4%   92.6%   98.8%  |     20.714 (+/-  1.6%) [spline]
# End time: 2019-02-26 10:53:57.603274
# Elapsed time: 0:00:35.681964
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 10:54:03.141089
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 34.526...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.02000
#   n_sig = 12.000 ... frac = 0.22000
#   n_sig = 15.000 ... frac = 0.34000
#   n_sig = 18.000 ... frac = 0.48000
#   n_sig = 21.000 ... frac = 0.68000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    8.40   16.80   25.20   33.60   42.00  | n_sig (relative error)
# 500      |          0.0%    3.6%   27.4%   73.6%   91.4%   99.0%  |     20.815 (+/-  1.1%) [spline]
# End time: 2019-02-26 10:54:39.300202
# Elapsed time: 0:00:36.159113

# %%
disc_1_llhextNone = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(1),llh_ext=None, cut_n_sigma=None, gamma=2, sigsub=False)
disc_1_llhext0 = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(1),llh_ext=np.radians(0), cut_n_sigma=None, gamma=2, sigsub=False)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 10:55:17.827296
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 30.547...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.02000
#   n_sig = 18.000 ... frac = 0.02000
#   n_sig = 21.000 ... frac = 0.02000
#   n_sig = 24.000 ... frac = 0.02000
#   n_sig = 27.000 ... frac = 0.08000
#   n_sig = 30.000 ... frac = 0.08000
#   n_sig = 33.000 ... frac = 0.16000
#   n_sig = 36.000 ... frac = 0.14000
#   n_sig = 39.000 ... frac = 0.30000
#   n_sig = 42.000 ... frac = 0.20000
#   n_sig = 45.000 ... frac = 0.44000
#   n_sig = 48.000 ... frac = 0.42000
#   n_sig = 51.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   20.40   40.80   61.20   81.60  102.00  | n_sig (relative error)
# 500      |          0.0%    2.6%   34.8%   85.0%   98.6%   99.8%  |     46.898 (+/-  1.3%) [spline]
# End time: 2019-02-26 10:56:15.431672
# Elapsed time: 0:00:57.604376
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 10:56:20.910032
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 37.184...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.02000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.02000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.02000
#   n_sig = 48.000 ... frac = 0.02000
#   n_sig = 51.000 ... frac = 0.06000
#   n_sig = 54.000 ... frac = 0.10000
#   n_sig = 57.000 ... frac = 0.10000
#   n_sig = 60.000 ... frac = 0.06000
#   n_sig = 63.000 ... frac = 0.06000
#   n_sig = 66.000 ... frac = 0.16000
#   n_sig = 69.000 ... frac = 0.30000
#   n_sig = 72.000 ... frac = 0.28000
#   n_sig = 75.000 ... frac = 0.24000
#   n_sig = 78.000 ... frac = 0.20000
#   n_sig = 81.000 ... frac = 0.34000
#   n_sig = 84.000 ... frac = 0.40000
#   n_sig = 87.000 ... frac = 0.38000
#   n_sig = 90.000 ... frac = 0.40000
#   n_sig = 93.000 ... frac = 0.50000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   37.20   74.40  111.60  148.80  186.00  | n_sig (relative error)
# 500      |          0.0%    0.6%   18.0%   67.0%   95.8%   99.2%  |     98.662 (+/-  1.1%) [spline]
# End time: 2019-02-26 10:57:27.267856
# Elapsed time: 0:01:06.357824

# %%
disc_2_llhextNone = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(2),llh_ext=None, cut_n_sigma=None, gamma=2, sigsub=False)
disc_2_llhext0 = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(2),llh_ext=np.radians(0), cut_n_sigma=None, gamma=2, sigsub=False)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:00:31.199569
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 40.707...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.02000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.02000
#   n_sig = 57.000 ... frac = 0.02000
#   n_sig = 60.000 ... frac = 0.10000
#   n_sig = 63.000 ... frac = 0.02000
#   n_sig = 66.000 ... frac = 0.02000
#   n_sig = 69.000 ... frac = 0.18000
#   n_sig = 72.000 ... frac = 0.06000
#   n_sig = 75.000 ... frac = 0.10000
#   n_sig = 78.000 ... frac = 0.18000
#   n_sig = 81.000 ... frac = 0.22000
#   n_sig = 84.000 ... frac = 0.26000
#   n_sig = 87.000 ... frac = 0.30000
#   n_sig = 90.000 ... frac = 0.36000
#   n_sig = 93.000 ... frac = 0.42000
#   n_sig = 96.000 ... frac = 0.56000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   38.40   76.80  115.20  153.60  192.00  | n_sig (relative error)
# 500      |          0.0%    0.0%   25.4%   87.2%  100.0%  100.0%  |     92.011 (+/-  0.9%) [spline]
# End time: 2019-02-26 11:02:13.640907
# Elapsed time: 0:01:42.441338
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:02:19.301929
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 31.414...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.00000
#   n_sig = 78.000 ... frac = 0.04000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.02000
#   n_sig = 87.000 ... frac = 0.00000
#   n_sig = 90.000 ... frac = 0.00000
#   n_sig = 93.000 ... frac = 0.00000
#   n_sig = 96.000 ... frac = 0.02000
#   n_sig = 99.000 ... frac = 0.02000
#   n_sig = 102.000 ... frac = 0.04000
#   n_sig = 105.000 ... frac = 0.02000
#   n_sig = 108.000 ... frac = 0.04000
#   n_sig = 111.000 ... frac = 0.10000
#   n_sig = 114.000 ... frac = 0.06000
#   n_sig = 117.000 ... frac = 0.04000
#   n_sig = 120.000 ... frac = 0.02000
#   n_sig = 123.000 ... frac = 0.02000
#   n_sig = 126.000 ... frac = 0.02000
#   n_sig = 129.000 ... frac = 0.02000
#   n_sig = 132.000 ... frac = 0.06000
#   n_sig = 135.000 ... frac = 0.06000
#   n_sig = 138.000 ... frac = 0.04000
#   n_sig = 141.000 ... frac = 0.08000
#   n_sig = 144.000 ... frac = 0.14000
#   n_sig = 147.000 ... frac = 0.08000
#   n_sig = 150.000 ... frac = 0.00000
#   n_sig = 153.000 ... frac = 0.00000
#   n_sig = 156.000 ... frac = 0.06000
#   n_sig = 159.000 ... frac = 0.08000
#   n_sig = 162.000 ... frac = 0.10000
#   n_sig = 165.000 ... frac = 0.10000
#   n_sig = 168.000 ... frac = 0.10000
#   n_sig = 171.000 ... frac = 0.18000
#   n_sig = 174.000 ... frac = 0.08000
#   n_sig = 177.000 ... frac = 0.22000
#   n_sig = 180.000 ... frac = 0.18000
#   n_sig = 183.000 ... frac = 0.20000
#   n_sig = 186.000 ... frac = 0.26000
#   n_sig = 189.000 ... frac = 0.30000
#   n_sig = 192.000 ... frac = 0.28000
#   n_sig = 195.000 ... frac = 0.30000
#   n_sig = 198.000 ... frac = 0.34000
#   n_sig = 201.000 ... frac = 0.24000
#   n_sig = 204.000 ... frac = 0.24000
#   n_sig = 207.000 ... frac = 0.32000
#   n_sig = 210.000 ... frac = 0.28000
#   n_sig = 213.000 ... frac = 0.34000
#   n_sig = 216.000 ... frac = 0.28000
#   n_sig = 219.000 ... frac = 0.38000
#   n_sig = 222.000 ... frac = 0.26000
#   n_sig = 225.000 ... frac = 0.38000
#   n_sig = 228.000 ... frac = 0.42000
#   n_sig = 231.000 ... frac = 0.36000
#   n_sig = 234.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   93.60  187.20  280.80  374.40  468.00  | n_sig (relative error)
# 500      |          0.0%    0.6%   26.2%   73.6%   93.2%  100.0%  |    233.013 (+/-  1.5%) [spline]
# End time: 2019-02-26 11:04:24.664817
# Elapsed time: 0:02:05.362888

# %%
disc_3_llhextNone = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(3),llh_ext=None, cut_n_sigma=None, gamma=2, sigsub=False)
disc_3_llhext0 = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(3),llh_ext=np.radians(0), cut_n_sigma=None, gamma=2, sigsub=False)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:04:52.211194
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 53.495...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.00000
#   n_sig = 78.000 ... frac = 0.00000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.02000
#   n_sig = 87.000 ... frac = 0.02000
#   n_sig = 90.000 ... frac = 0.06000
#   n_sig = 93.000 ... frac = 0.02000
#   n_sig = 96.000 ... frac = 0.02000
#   n_sig = 99.000 ... frac = 0.04000
#   n_sig = 102.000 ... frac = 0.02000
#   n_sig = 105.000 ... frac = 0.06000
#   n_sig = 108.000 ... frac = 0.10000
#   n_sig = 111.000 ... frac = 0.04000
#   n_sig = 114.000 ... frac = 0.04000
#   n_sig = 117.000 ... frac = 0.08000
#   n_sig = 120.000 ... frac = 0.12000
#   n_sig = 123.000 ... frac = 0.16000
#   n_sig = 126.000 ... frac = 0.08000
#   n_sig = 129.000 ... frac = 0.14000
#   n_sig = 132.000 ... frac = 0.26000
#   n_sig = 135.000 ... frac = 0.32000
#   n_sig = 138.000 ... frac = 0.38000
#   n_sig = 141.000 ... frac = 0.42000
#   n_sig = 144.000 ... frac = 0.44000
#   n_sig = 147.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   58.80  117.60  176.40  235.20  294.00  | n_sig (relative error)
# 500      |          0.0%    0.0%   15.8%   80.6%   99.4%  100.0%  |    148.596 (+/-  0.7%) [spline]
# End time: 2019-02-26 11:06:52.348886
# Elapsed time: 0:02:00.137692
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:06:58.515801
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 34.517...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.00000
#   n_sig = 78.000 ... frac = 0.00000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.00000
#   n_sig = 87.000 ... frac = 0.00000
#   n_sig = 90.000 ... frac = 0.00000
#   n_sig = 93.000 ... frac = 0.00000
#   n_sig = 96.000 ... frac = 0.00000
#   n_sig = 99.000 ... frac = 0.00000
#   n_sig = 102.000 ... frac = 0.00000
#   n_sig = 105.000 ... frac = 0.00000
#   n_sig = 108.000 ... frac = 0.00000
#   n_sig = 111.000 ... frac = 0.00000
#   n_sig = 114.000 ... frac = 0.00000
#   n_sig = 117.000 ... frac = 0.00000
#   n_sig = 120.000 ... frac = 0.00000
#   n_sig = 123.000 ... frac = 0.00000
#   n_sig = 126.000 ... frac = 0.02000
#   n_sig = 129.000 ... frac = 0.02000
#   n_sig = 132.000 ... frac = 0.00000
#   n_sig = 135.000 ... frac = 0.00000
#   n_sig = 138.000 ... frac = 0.00000
#   n_sig = 141.000 ... frac = 0.00000
#   n_sig = 144.000 ... frac = 0.00000
#   n_sig = 147.000 ... frac = 0.02000
#   n_sig = 150.000 ... frac = 0.00000
#   n_sig = 153.000 ... frac = 0.00000
#   n_sig = 156.000 ... frac = 0.00000
#   n_sig = 159.000 ... frac = 0.00000
#   n_sig = 162.000 ... frac = 0.00000
#   n_sig = 165.000 ... frac = 0.00000
#   n_sig = 168.000 ... frac = 0.00000
#   n_sig = 171.000 ... frac = 0.00000
#   n_sig = 174.000 ... frac = 0.02000
#   n_sig = 177.000 ... frac = 0.02000
#   n_sig = 180.000 ... frac = 0.00000
#   n_sig = 183.000 ... frac = 0.00000
#   n_sig = 186.000 ... frac = 0.04000
#   n_sig = 189.000 ... frac = 0.02000
#   n_sig = 192.000 ... frac = 0.02000
#   n_sig = 195.000 ... frac = 0.02000
#   n_sig = 198.000 ... frac = 0.00000
#   n_sig = 201.000 ... frac = 0.02000
#   n_sig = 204.000 ... frac = 0.00000
#   n_sig = 207.000 ... frac = 0.04000
#   n_sig = 210.000 ... frac = 0.04000
#   n_sig = 213.000 ... frac = 0.02000
#   n_sig = 216.000 ... frac = 0.00000
#   n_sig = 219.000 ... frac = 0.00000
#   n_sig = 222.000 ... frac = 0.02000
#   n_sig = 225.000 ... frac = 0.00000
#   n_sig = 228.000 ... frac = 0.02000
#   n_sig = 231.000 ... frac = 0.02000
#   n_sig = 234.000 ... frac = 0.04000
#   n_sig = 237.000 ... frac = 0.04000
#   n_sig = 240.000 ... frac = 0.02000
#   n_sig = 243.000 ... frac = 0.02000
#   n_sig = 246.000 ... frac = 0.04000
#   n_sig = 249.000 ... frac = 0.06000
#   n_sig = 252.000 ... frac = 0.02000
#   n_sig = 255.000 ... frac = 0.00000
#   n_sig = 258.000 ... frac = 0.02000
#   n_sig = 261.000 ... frac = 0.02000
#   n_sig = 264.000 ... frac = 0.06000
#   n_sig = 267.000 ... frac = 0.00000
#   n_sig = 270.000 ... frac = 0.08000
#   n_sig = 273.000 ... frac = 0.00000
#   n_sig = 276.000 ... frac = 0.04000
#   n_sig = 279.000 ... frac = 0.04000
#   n_sig = 282.000 ... frac = 0.06000
#   n_sig = 285.000 ... frac = 0.02000
#   n_sig = 288.000 ... frac = 0.04000
#   n_sig = 291.000 ... frac = 0.14000
#   n_sig = 294.000 ... frac = 0.08000
#   n_sig = 297.000 ... frac = 0.06000
#   n_sig = 300.000 ... frac = 0.04000
#   n_sig = 303.000 ... frac = 0.06000
#   n_sig = 306.000 ... frac = 0.12000
#   n_sig = 309.000 ... frac = 0.12000
#   n_sig = 312.000 ... frac = 0.10000
#   n_sig = 315.000 ... frac = 0.08000
#   n_sig = 318.000 ... frac = 0.08000
#   n_sig = 321.000 ... frac = 0.08000
#   n_sig = 324.000 ... frac = 0.16000
#   n_sig = 327.000 ... frac = 0.20000
#   n_sig = 330.000 ... frac = 0.12000
#   n_sig = 333.000 ... frac = 0.10000
#   n_sig = 336.000 ... frac = 0.24000
#   n_sig = 339.000 ... frac = 0.16000
#   n_sig = 342.000 ... frac = 0.20000
#   n_sig = 345.000 ... frac = 0.22000
#   n_sig = 348.000 ... frac = 0.16000
#   n_sig = 351.000 ... frac = 0.16000
#   n_sig = 354.000 ... frac = 0.18000
#   n_sig = 357.000 ... frac = 0.28000
#   n_sig = 360.000 ... frac = 0.24000
#   n_sig = 363.000 ... frac = 0.20000
#   n_sig = 366.000 ... frac = 0.22000
#   n_sig = 369.000 ... frac = 0.18000
#   n_sig = 372.000 ... frac = 0.26000
#   n_sig = 375.000 ... frac = 0.26000
#   n_sig = 378.000 ... frac = 0.20000
#   n_sig = 381.000 ... frac = 0.30000
#   n_sig = 384.000 ... frac = 0.18000
#   n_sig = 387.000 ... frac = 0.24000
#   n_sig = 390.000 ... frac = 0.20000
#   n_sig = 393.000 ... frac = 0.18000
#   n_sig = 396.000 ... frac = 0.30000
#   n_sig = 399.000 ... frac = 0.30000
#   n_sig = 402.000 ... frac = 0.24000
#   n_sig = 405.000 ... frac = 0.34000
#   n_sig = 408.000 ... frac = 0.38000
#   n_sig = 411.000 ... frac = 0.36000
#   n_sig = 414.000 ... frac = 0.26000
#   n_sig = 417.000 ... frac = 0.32000
#   n_sig = 420.000 ... frac = 0.32000
#   n_sig = 423.000 ... frac = 0.34000
#   n_sig = 426.000 ... frac = 0.46000
#   n_sig = 429.000 ... frac = 0.32000
#   n_sig = 432.000 ... frac = 0.34000
#   n_sig = 435.000 ... frac = 0.32000
#   n_sig = 438.000 ... frac = 0.42000
#   n_sig = 441.000 ... frac = 0.40000
#   n_sig = 444.000 ... frac = 0.48000
#   n_sig = 447.000 ... frac = 0.40000
#   n_sig = 450.000 ... frac = 0.46000
#   n_sig = 453.000 ... frac = 0.56000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00  181.20  362.40  543.60  724.80  906.00  | n_sig (relative error)
# 500      |          0.0%    0.2%   19.0%   63.4%   93.2%   99.6%  |    488.398 (+/-  1.5%) [spline]
# End time: 2019-02-26 11:10:36.875966
# Elapsed time: 0:03:38.360165

# %%
disc_4_llhextNone = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(4),llh_ext=None, cut_n_sigma=None, gamma=2, sigsub=False)
disc_4_llhext0 = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(4),llh_ext=np.radians(0), cut_n_sigma=None, gamma=2, sigsub=False)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:12:37.949857
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 26.843...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.02000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.02000
#   n_sig = 69.000 ... frac = 0.06000
#   n_sig = 72.000 ... frac = 0.02000
#   n_sig = 75.000 ... frac = 0.02000
#   n_sig = 78.000 ... frac = 0.02000
#   n_sig = 81.000 ... frac = 0.04000
#   n_sig = 84.000 ... frac = 0.06000
#   n_sig = 87.000 ... frac = 0.02000
#   n_sig = 90.000 ... frac = 0.04000
#   n_sig = 93.000 ... frac = 0.08000
#   n_sig = 96.000 ... frac = 0.12000
#   n_sig = 99.000 ... frac = 0.06000
#   n_sig = 102.000 ... frac = 0.16000
#   n_sig = 105.000 ... frac = 0.20000
#   n_sig = 108.000 ... frac = 0.34000
#   n_sig = 111.000 ... frac = 0.26000
#   n_sig = 114.000 ... frac = 0.32000
#   n_sig = 117.000 ... frac = 0.26000
#   n_sig = 120.000 ... frac = 0.34000
#   n_sig = 123.000 ... frac = 0.42000
#   n_sig = 126.000 ... frac = 0.38000
#   n_sig = 129.000 ... frac = 0.42000
#   n_sig = 132.000 ... frac = 0.44000
#   n_sig = 135.000 ... frac = 0.56000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   54.00  108.00  162.00  216.00  270.00  | n_sig (relative error)
# 500      |          0.0%    0.2%   18.6%   78.4%   99.2%  100.0%  |    136.326 (+/-  0.7%) [spline]
# End time: 2019-02-26 11:14:54.813678
# Elapsed time: 0:02:16.863821
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:14:59.835944
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 39.616...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.00000
#   n_sig = 78.000 ... frac = 0.00000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.00000
#   n_sig = 87.000 ... frac = 0.00000
#   n_sig = 90.000 ... frac = 0.00000
#   n_sig = 93.000 ... frac = 0.00000
#   n_sig = 96.000 ... frac = 0.00000
#   n_sig = 99.000 ... frac = 0.00000
#   n_sig = 102.000 ... frac = 0.00000
#   n_sig = 105.000 ... frac = 0.00000
#   n_sig = 108.000 ... frac = 0.00000
#   n_sig = 111.000 ... frac = 0.00000
#   n_sig = 114.000 ... frac = 0.00000
#   n_sig = 117.000 ... frac = 0.00000
#   n_sig = 120.000 ... frac = 0.00000
#   n_sig = 123.000 ... frac = 0.00000
#   n_sig = 126.000 ... frac = 0.00000
#   n_sig = 129.000 ... frac = 0.00000
#   n_sig = 132.000 ... frac = 0.00000
#   n_sig = 135.000 ... frac = 0.00000
#   n_sig = 138.000 ... frac = 0.00000
#   n_sig = 141.000 ... frac = 0.00000
#   n_sig = 144.000 ... frac = 0.00000
#   n_sig = 147.000 ... frac = 0.00000
#   n_sig = 150.000 ... frac = 0.00000
#   n_sig = 153.000 ... frac = 0.00000
#   n_sig = 156.000 ... frac = 0.00000
#   n_sig = 159.000 ... frac = 0.00000
#   n_sig = 162.000 ... frac = 0.00000
#   n_sig = 165.000 ... frac = 0.00000
#   n_sig = 168.000 ... frac = 0.00000
#   n_sig = 171.000 ... frac = 0.00000
#   n_sig = 174.000 ... frac = 0.00000
#   n_sig = 177.000 ... frac = 0.00000
#   n_sig = 180.000 ... frac = 0.00000
#   n_sig = 183.000 ... frac = 0.00000
#   n_sig = 186.000 ... frac = 0.00000
#   n_sig = 189.000 ... frac = 0.00000
#   n_sig = 192.000 ... frac = 0.00000
#   n_sig = 195.000 ... frac = 0.00000
#   n_sig = 198.000 ... frac = 0.00000
#   n_sig = 201.000 ... frac = 0.00000
#   n_sig = 204.000 ... frac = 0.00000
#   n_sig = 207.000 ... frac = 0.00000
#   n_sig = 210.000 ... frac = 0.00000
#   n_sig = 213.000 ... frac = 0.00000
#   n_sig = 216.000 ... frac = 0.00000
#   n_sig = 219.000 ... frac = 0.00000
#   n_sig = 222.000 ... frac = 0.00000
#   n_sig = 225.000 ... frac = 0.00000
#   n_sig = 228.000 ... frac = 0.00000
#   n_sig = 231.000 ... frac = 0.00000
#   n_sig = 234.000 ... frac = 0.00000
#   n_sig = 237.000 ... frac = 0.00000
#   n_sig = 240.000 ... frac = 0.00000
#   n_sig = 243.000 ... frac = 0.00000
#   n_sig = 246.000 ... frac = 0.00000
#   n_sig = 249.000 ... frac = 0.00000
#   n_sig = 252.000 ... frac = 0.02000
#   n_sig = 255.000 ... frac = 0.00000
#   n_sig = 258.000 ... frac = 0.02000
#   n_sig = 261.000 ... frac = 0.00000
#   n_sig = 264.000 ... frac = 0.00000
#   n_sig = 267.000 ... frac = 0.00000
#   n_sig = 270.000 ... frac = 0.00000
#   n_sig = 273.000 ... frac = 0.00000
#   n_sig = 276.000 ... frac = 0.00000
#   n_sig = 279.000 ... frac = 0.00000
#   n_sig = 282.000 ... frac = 0.00000
#   n_sig = 285.000 ... frac = 0.00000
#   n_sig = 288.000 ... frac = 0.00000
#   n_sig = 291.000 ... frac = 0.00000
#   n_sig = 294.000 ... frac = 0.00000
#   n_sig = 297.000 ... frac = 0.00000
#   n_sig = 300.000 ... frac = 0.00000
#   n_sig = 303.000 ... frac = 0.00000
#   n_sig = 306.000 ... frac = 0.00000
#   n_sig = 309.000 ... frac = 0.00000
#   n_sig = 312.000 ... frac = 0.00000
#   n_sig = 315.000 ... frac = 0.00000
#   n_sig = 318.000 ... frac = 0.00000
#   n_sig = 321.000 ... frac = 0.02000
#   n_sig = 324.000 ... frac = 0.00000
#   n_sig = 327.000 ... frac = 0.00000
#   n_sig = 330.000 ... frac = 0.00000
#   n_sig = 333.000 ... frac = 0.02000
#   n_sig = 336.000 ... frac = 0.02000
#   n_sig = 339.000 ... frac = 0.00000
#   n_sig = 342.000 ... frac = 0.02000
#   n_sig = 345.000 ... frac = 0.00000
#   n_sig = 348.000 ... frac = 0.02000
#   n_sig = 351.000 ... frac = 0.00000
#   n_sig = 354.000 ... frac = 0.02000
#   n_sig = 357.000 ... frac = 0.00000
#   n_sig = 360.000 ... frac = 0.02000
#   n_sig = 363.000 ... frac = 0.00000
#   n_sig = 366.000 ... frac = 0.02000
#   n_sig = 369.000 ... frac = 0.00000
#   n_sig = 372.000 ... frac = 0.02000
#   n_sig = 375.000 ... frac = 0.00000
#   n_sig = 378.000 ... frac = 0.02000
#   n_sig = 381.000 ... frac = 0.04000
#   n_sig = 384.000 ... frac = 0.02000
#   n_sig = 387.000 ... frac = 0.02000
#   n_sig = 390.000 ... frac = 0.04000
#   n_sig = 393.000 ... frac = 0.02000
#   n_sig = 396.000 ... frac = 0.02000
#   n_sig = 399.000 ... frac = 0.00000
#   n_sig = 402.000 ... frac = 0.00000
#   n_sig = 405.000 ... frac = 0.02000
#   n_sig = 408.000 ... frac = 0.06000
#   n_sig = 411.000 ... frac = 0.02000
#   n_sig = 414.000 ... frac = 0.04000
#   n_sig = 417.000 ... frac = 0.00000
#   n_sig = 420.000 ... frac = 0.06000
#   n_sig = 423.000 ... frac = 0.04000
#   n_sig = 426.000 ... frac = 0.02000
#   n_sig = 429.000 ... frac = 0.02000
#   n_sig = 432.000 ... frac = 0.00000
#   n_sig = 435.000 ... frac = 0.08000
#   n_sig = 438.000 ... frac = 0.02000
#   n_sig = 441.000 ... frac = 0.04000
#   n_sig = 444.000 ... frac = 0.00000
#   n_sig = 447.000 ... frac = 0.04000
#   n_sig = 450.000 ... frac = 0.06000
#   n_sig = 453.000 ... frac = 0.02000
#   n_sig = 456.000 ... frac = 0.04000
#   n_sig = 459.000 ... frac = 0.00000
#   n_sig = 462.000 ... frac = 0.06000
#   n_sig = 465.000 ... frac = 0.00000
#   n_sig = 468.000 ... frac = 0.06000
#   n_sig = 471.000 ... frac = 0.04000
#   n_sig = 474.000 ... frac = 0.06000
#   n_sig = 477.000 ... frac = 0.04000
#   n_sig = 480.000 ... frac = 0.06000
#   n_sig = 483.000 ... frac = 0.04000
#   n_sig = 486.000 ... frac = 0.06000
#   n_sig = 489.000 ... frac = 0.04000
#   n_sig = 492.000 ... frac = 0.04000
#   n_sig = 495.000 ... frac = 0.08000
#   n_sig = 498.000 ... frac = 0.02000
#   n_sig = 501.000 ... frac = 0.04000
#   n_sig = 504.000 ... frac = 0.06000
#   n_sig = 507.000 ... frac = 0.08000
#   n_sig = 510.000 ... frac = 0.02000
#   n_sig = 513.000 ... frac = 0.02000
#   n_sig = 516.000 ... frac = 0.06000
#   n_sig = 519.000 ... frac = 0.04000
#   n_sig = 522.000 ... frac = 0.08000
#   n_sig = 525.000 ... frac = 0.08000
#   n_sig = 528.000 ... frac = 0.02000
#   n_sig = 531.000 ... frac = 0.06000
#   n_sig = 534.000 ... frac = 0.14000
#   n_sig = 537.000 ... frac = 0.06000
#   n_sig = 540.000 ... frac = 0.04000
#   n_sig = 543.000 ... frac = 0.12000
#   n_sig = 546.000 ... frac = 0.06000
#   n_sig = 549.000 ... frac = 0.12000
#   n_sig = 552.000 ... frac = 0.10000
#   n_sig = 555.000 ... frac = 0.08000
#   n_sig = 558.000 ... frac = 0.10000
#   n_sig = 561.000 ... frac = 0.08000
#   n_sig = 564.000 ... frac = 0.06000
#   n_sig = 567.000 ... frac = 0.08000
#   n_sig = 570.000 ... frac = 0.12000
#   n_sig = 573.000 ... frac = 0.14000
#   n_sig = 576.000 ... frac = 0.10000
#   n_sig = 579.000 ... frac = 0.06000
#   n_sig = 582.000 ... frac = 0.08000
#   n_sig = 585.000 ... frac = 0.08000
#   n_sig = 588.000 ... frac = 0.14000
#   n_sig = 591.000 ... frac = 0.08000
#   n_sig = 594.000 ... frac = 0.18000
#   n_sig = 597.000 ... frac = 0.10000
#   n_sig = 600.000 ... frac = 0.12000
#   n_sig = 603.000 ... frac = 0.20000
#   n_sig = 606.000 ... frac = 0.18000
#   n_sig = 609.000 ... frac = 0.16000
#   n_sig = 612.000 ... frac = 0.16000
#   n_sig = 615.000 ... frac = 0.16000
#   n_sig = 618.000 ... frac = 0.12000
#   n_sig = 621.000 ... frac = 0.10000
#   n_sig = 624.000 ... frac = 0.18000
#   n_sig = 627.000 ... frac = 0.10000
#   n_sig = 630.000 ... frac = 0.16000
#   n_sig = 633.000 ... frac = 0.20000
#   n_sig = 636.000 ... frac = 0.16000
#   n_sig = 639.000 ... frac = 0.16000
#   n_sig = 642.000 ... frac = 0.20000
#   n_sig = 645.000 ... frac = 0.12000
#   n_sig = 648.000 ... frac = 0.22000
#   n_sig = 651.000 ... frac = 0.24000
#   n_sig = 654.000 ... frac = 0.18000
#   n_sig = 657.000 ... frac = 0.16000
#   n_sig = 660.000 ... frac = 0.24000
#   n_sig = 663.000 ... frac = 0.14000
#   n_sig = 666.000 ... frac = 0.12000
#   n_sig = 669.000 ... frac = 0.24000
#   n_sig = 672.000 ... frac = 0.24000
#   n_sig = 675.000 ... frac = 0.36000
#   n_sig = 678.000 ... frac = 0.32000
#   n_sig = 681.000 ... frac = 0.16000
#   n_sig = 684.000 ... frac = 0.24000
#   n_sig = 687.000 ... frac = 0.30000
#   n_sig = 690.000 ... frac = 0.34000
#   n_sig = 693.000 ... frac = 0.38000
#   n_sig = 696.000 ... frac = 0.24000
#   n_sig = 699.000 ... frac = 0.24000
#   n_sig = 702.000 ... frac = 0.30000
#   n_sig = 705.000 ... frac = 0.36000
#   n_sig = 708.000 ... frac = 0.28000
#   n_sig = 711.000 ... frac = 0.34000
#   n_sig = 714.000 ... frac = 0.26000
#   n_sig = 717.000 ... frac = 0.34000
#   n_sig = 720.000 ... frac = 0.22000
#   n_sig = 723.000 ... frac = 0.24000
#   n_sig = 726.000 ... frac = 0.26000
#   n_sig = 729.000 ... frac = 0.40000
#   n_sig = 732.000 ... frac = 0.36000
#   n_sig = 735.000 ... frac = 0.26000
#   n_sig = 738.000 ... frac = 0.26000
#   n_sig = 741.000 ... frac = 0.44000
#   n_sig = 744.000 ... frac = 0.30000
#   n_sig = 747.000 ... frac = 0.44000
#   n_sig = 750.000 ... frac = 0.40000
#   n_sig = 753.000 ... frac = 0.48000
#   n_sig = 756.000 ... frac = 0.38000
#   n_sig = 759.000 ... frac = 0.44000
#   n_sig = 762.000 ... frac = 0.34000
#   n_sig = 765.000 ... frac = 0.46000
#   n_sig = 768.000 ... frac = 0.40000
#   n_sig = 771.000 ... frac = 0.50000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00  308.40  616.80  925.20 1233.60 1542.00  | n_sig (relative error)
# 500      |          0.0%    0.2%   15.6%   66.4%   93.8%  100.0%  |    823.914 (+/-  1.1%) [spline]
# End time: 2019-02-26 11:20:56.815499
# Elapsed time: 0:05:56.979555

# %%
disc_5_llhextNone = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(5),llh_ext=None, cut_n_sigma=None, gamma=2, sigsub=False)
disc_5_llhext0 = get_disc(ana7,ra=0,sindec=sindec16,ext=np.radians(5),llh_ext=np.radians(0), cut_n_sigma=None, gamma=2, sigsub=False)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:22:36.695538
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 24.647...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.00000
#   n_sig = 78.000 ... frac = 0.00000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.02000
#   n_sig = 87.000 ... frac = 0.00000
#   n_sig = 90.000 ... frac = 0.00000
#   n_sig = 93.000 ... frac = 0.02000
#   n_sig = 96.000 ... frac = 0.02000
#   n_sig = 99.000 ... frac = 0.04000
#   n_sig = 102.000 ... frac = 0.04000
#   n_sig = 105.000 ... frac = 0.02000
#   n_sig = 108.000 ... frac = 0.08000
#   n_sig = 111.000 ... frac = 0.06000
#   n_sig = 114.000 ... frac = 0.10000
#   n_sig = 117.000 ... frac = 0.12000
#   n_sig = 120.000 ... frac = 0.14000
#   n_sig = 123.000 ... frac = 0.12000
#   n_sig = 126.000 ... frac = 0.18000
#   n_sig = 129.000 ... frac = 0.16000
#   n_sig = 132.000 ... frac = 0.22000
#   n_sig = 135.000 ... frac = 0.14000
#   n_sig = 138.000 ... frac = 0.22000
#   n_sig = 141.000 ... frac = 0.28000
#   n_sig = 144.000 ... frac = 0.40000
#   n_sig = 147.000 ... frac = 0.32000
#   n_sig = 150.000 ... frac = 0.34000
#   n_sig = 153.000 ... frac = 0.18000
#   n_sig = 156.000 ... frac = 0.40000
#   n_sig = 159.000 ... frac = 0.46000
#   n_sig = 162.000 ... frac = 0.58000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   64.80  129.60  194.40  259.20  324.00  | n_sig (relative error)
# 500      |          0.0%    0.0%   15.6%   77.8%   99.6%  100.0%  |    165.460 (+/-  0.9%) [spline]
# End time: 2019-02-26 11:25:39.581211
# Elapsed time: 0:03:02.885673
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-26 11:25:45.196860
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 30.745...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.00000
#   n_sig = 78.000 ... frac = 0.00000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.00000
#   n_sig = 87.000 ... frac = 0.00000
#   n_sig = 90.000 ... frac = 0.00000
#   n_sig = 93.000 ... frac = 0.00000
#   n_sig = 96.000 ... frac = 0.00000
#   n_sig = 99.000 ... frac = 0.00000
#   n_sig = 102.000 ... frac = 0.00000
#   n_sig = 105.000 ... frac = 0.00000
#   n_sig = 108.000 ... frac = 0.00000
#   n_sig = 111.000 ... frac = 0.00000
#   n_sig = 114.000 ... frac = 0.00000
#   n_sig = 117.000 ... frac = 0.00000
#   n_sig = 120.000 ... frac = 0.00000
#   n_sig = 123.000 ... frac = 0.00000
#   n_sig = 126.000 ... frac = 0.00000
#   n_sig = 129.000 ... frac = 0.00000
#   n_sig = 132.000 ... frac = 0.00000
#   n_sig = 135.000 ... frac = 0.00000
#   n_sig = 138.000 ... frac = 0.00000
#   n_sig = 141.000 ... frac = 0.00000
#   n_sig = 144.000 ... frac = 0.00000
#   n_sig = 147.000 ... frac = 0.00000
#   n_sig = 150.000 ... frac = 0.00000
#   n_sig = 153.000 ... frac = 0.00000
#   n_sig = 156.000 ... frac = 0.00000
#   n_sig = 159.000 ... frac = 0.00000
#   n_sig = 162.000 ... frac = 0.00000
#   n_sig = 165.000 ... frac = 0.00000
#   n_sig = 168.000 ... frac = 0.00000
#   n_sig = 171.000 ... frac = 0.00000
#   n_sig = 174.000 ... frac = 0.00000
#   n_sig = 177.000 ... frac = 0.00000
#   n_sig = 180.000 ... frac = 0.00000
#   n_sig = 183.000 ... frac = 0.00000
#   n_sig = 186.000 ... frac = 0.00000
#   n_sig = 189.000 ... frac = 0.00000
#   n_sig = 192.000 ... frac = 0.00000
#   n_sig = 195.000 ... frac = 0.00000
#   n_sig = 198.000 ... frac = 0.00000
#   n_sig = 201.000 ... frac = 0.00000
#   n_sig = 204.000 ... frac = 0.00000
#   n_sig = 207.000 ... frac = 0.00000
#   n_sig = 210.000 ... frac = 0.00000
#   n_sig = 213.000 ... frac = 0.00000
#   n_sig = 216.000 ... frac = 0.00000
#   n_sig = 219.000 ... frac = 0.00000
#   n_sig = 222.000 ... frac = 0.00000
#   n_sig = 225.000 ... frac = 0.00000
#   n_sig = 228.000 ... frac = 0.00000
#   n_sig = 231.000 ... frac = 0.00000
#   n_sig = 234.000 ... frac = 0.00000
#   n_sig = 237.000 ... frac = 0.00000
#   n_sig = 240.000 ... frac = 0.00000
#   n_sig = 243.000 ... frac = 0.00000
#   n_sig = 246.000 ... frac = 0.00000
#   n_sig = 249.000 ... frac = 0.00000
#   n_sig = 252.000 ... frac = 0.00000
#   n_sig = 255.000 ... frac = 0.00000
#   n_sig = 258.000 ... frac = 0.00000
#   n_sig = 261.000 ... frac = 0.00000
#   n_sig = 264.000 ... frac = 0.00000
#   n_sig = 267.000 ... frac = 0.00000
#   n_sig = 270.000 ... frac = 0.00000
#   n_sig = 273.000 ... frac = 0.00000
#   n_sig = 276.000 ... frac = 0.00000
#   n_sig = 279.000 ... frac = 0.00000
#   n_sig = 282.000 ... frac = 0.00000
#   n_sig = 285.000 ... frac = 0.00000
#   n_sig = 288.000 ... frac = 0.00000
#   n_sig = 291.000 ... frac = 0.00000
#   n_sig = 294.000 ... frac = 0.00000
#   n_sig = 297.000 ... frac = 0.00000
#   n_sig = 300.000 ... frac = 0.00000
#   n_sig = 303.000 ... frac = 0.00000
#   n_sig = 306.000 ... frac = 0.00000
#   n_sig = 309.000 ... frac = 0.00000
#   n_sig = 312.000 ... frac = 0.00000
#   n_sig = 315.000 ... frac = 0.00000
#   n_sig = 318.000 ... frac = 0.00000
#   n_sig = 321.000 ... frac = 0.00000
#   n_sig = 324.000 ... frac = 0.00000
#   n_sig = 327.000 ... frac = 0.00000
#   n_sig = 330.000 ... frac = 0.00000
#   n_sig = 333.000 ... frac = 0.00000
#   n_sig = 336.000 ... frac = 0.00000
#   n_sig = 339.000 ... frac = 0.00000
#   n_sig = 342.000 ... frac = 0.02000
#   n_sig = 345.000 ... frac = 0.00000
#   n_sig = 348.000 ... frac = 0.02000
#   n_sig = 351.000 ... frac = 0.00000
#   n_sig = 354.000 ... frac = 0.00000
#   n_sig = 357.000 ... frac = 0.00000
#   n_sig = 360.000 ... frac = 0.00000
#   n_sig = 363.000 ... frac = 0.00000
#   n_sig = 366.000 ... frac = 0.00000
#   n_sig = 369.000 ... frac = 0.00000
#   n_sig = 372.000 ... frac = 0.00000
#   n_sig = 375.000 ... frac = 0.00000
#   n_sig = 378.000 ... frac = 0.00000
#   n_sig = 381.000 ... frac = 0.02000
#   n_sig = 384.000 ... frac = 0.02000
#   n_sig = 387.000 ... frac = 0.00000
#   n_sig = 390.000 ... frac = 0.04000
#   n_sig = 393.000 ... frac = 0.04000
#   n_sig = 396.000 ... frac = 0.00000
#   n_sig = 399.000 ... frac = 0.02000
#   n_sig = 402.000 ... frac = 0.00000
#   n_sig = 405.000 ... frac = 0.00000
#   n_sig = 408.000 ... frac = 0.00000
#   n_sig = 411.000 ... frac = 0.00000
#   n_sig = 414.000 ... frac = 0.00000
#   n_sig = 417.000 ... frac = 0.02000
#   n_sig = 420.000 ... frac = 0.02000
#   n_sig = 423.000 ... frac = 0.00000
#   n_sig = 426.000 ... frac = 0.00000
#   n_sig = 429.000 ... frac = 0.04000
#   n_sig = 432.000 ... frac = 0.00000
#   n_sig = 435.000 ... frac = 0.00000
#   n_sig = 438.000 ... frac = 0.02000
#   n_sig = 441.000 ... frac = 0.00000
#   n_sig = 444.000 ... frac = 0.00000
#   n_sig = 447.000 ... frac = 0.02000
#   n_sig = 450.000 ... frac = 0.00000
#   n_sig = 453.000 ... frac = 0.00000
#   n_sig = 456.000 ... frac = 0.00000
#   n_sig = 459.000 ... frac = 0.00000
#   n_sig = 462.000 ... frac = 0.00000
#   n_sig = 465.000 ... frac = 0.00000
#   n_sig = 468.000 ... frac = 0.00000
#   n_sig = 471.000 ... frac = 0.00000
#   n_sig = 474.000 ... frac = 0.00000
#   n_sig = 477.000 ... frac = 0.02000
#   n_sig = 480.000 ... frac = 0.00000
#   n_sig = 483.000 ... frac = 0.04000
#   n_sig = 486.000 ... frac = 0.00000
#   n_sig = 489.000 ... frac = 0.02000
#   n_sig = 492.000 ... frac = 0.00000
#   n_sig = 495.000 ... frac = 0.04000
#   n_sig = 498.000 ... frac = 0.02000
#   n_sig = 501.000 ... frac = 0.02000
#   n_sig = 504.000 ... frac = 0.00000
#   n_sig = 507.000 ... frac = 0.04000
#   n_sig = 510.000 ... frac = 0.00000
#   n_sig = 513.000 ... frac = 0.04000
#   n_sig = 516.000 ... frac = 0.06000
#   n_sig = 519.000 ... frac = 0.00000
#   n_sig = 522.000 ... frac = 0.02000
#   n_sig = 525.000 ... frac = 0.04000
#   n_sig = 528.000 ... frac = 0.04000
#   n_sig = 531.000 ... frac = 0.04000
#   n_sig = 534.000 ... frac = 0.06000
#   n_sig = 537.000 ... frac = 0.02000
#   n_sig = 540.000 ... frac = 0.02000
#   n_sig = 543.000 ... frac = 0.00000
#   n_sig = 546.000 ... frac = 0.04000
#   n_sig = 549.000 ... frac = 0.02000
#   n_sig = 552.000 ... frac = 0.00000
#   n_sig = 555.000 ... frac = 0.08000
#   n_sig = 558.000 ... frac = 0.00000
#   n_sig = 561.000 ... frac = 0.08000
#   n_sig = 564.000 ... frac = 0.04000
#   n_sig = 567.000 ... frac = 0.04000
#   n_sig = 570.000 ... frac = 0.02000
#   n_sig = 573.000 ... frac = 0.04000
#   n_sig = 576.000 ... frac = 0.02000
#   n_sig = 579.000 ... frac = 0.04000
#   n_sig = 582.000 ... frac = 0.00000
#   n_sig = 585.000 ... frac = 0.06000
#   n_sig = 588.000 ... frac = 0.08000
#   n_sig = 591.000 ... frac = 0.00000
#   n_sig = 594.000 ... frac = 0.08000
#   n_sig = 597.000 ... frac = 0.08000
#   n_sig = 600.000 ... frac = 0.04000
#   n_sig = 603.000 ... frac = 0.00000
#   n_sig = 606.000 ... frac = 0.06000
#   n_sig = 609.000 ... frac = 0.06000
#   n_sig = 612.000 ... frac = 0.08000
#   n_sig = 615.000 ... frac = 0.08000
#   n_sig = 618.000 ... frac = 0.06000
#   n_sig = 621.000 ... frac = 0.06000
#   n_sig = 624.000 ... frac = 0.02000
#   n_sig = 627.000 ... frac = 0.02000
#   n_sig = 630.000 ... frac = 0.06000
#   n_sig = 633.000 ... frac = 0.02000
#   n_sig = 636.000 ... frac = 0.02000
#   n_sig = 639.000 ... frac = 0.02000
#   n_sig = 642.000 ... frac = 0.10000
#   n_sig = 645.000 ... frac = 0.02000
#   n_sig = 648.000 ... frac = 0.06000
#   n_sig = 651.000 ... frac = 0.08000
#   n_sig = 654.000 ... frac = 0.02000
#   n_sig = 657.000 ... frac = 0.02000
#   n_sig = 660.000 ... frac = 0.08000
#   n_sig = 663.000 ... frac = 0.06000
#   n_sig = 666.000 ... frac = 0.10000
#   n_sig = 669.000 ... frac = 0.04000
#   n_sig = 672.000 ... frac = 0.06000
#   n_sig = 675.000 ... frac = 0.04000
#   n_sig = 678.000 ... frac = 0.12000
#   n_sig = 681.000 ... frac = 0.12000
#   n_sig = 684.000 ... frac = 0.06000
#   n_sig = 687.000 ... frac = 0.02000
#   n_sig = 690.000 ... frac = 0.10000
#   n_sig = 693.000 ... frac = 0.10000
#   n_sig = 696.000 ... frac = 0.06000
#   n_sig = 699.000 ... frac = 0.04000
#   n_sig = 702.000 ... frac = 0.02000
#   n_sig = 705.000 ... frac = 0.10000
#   n_sig = 708.000 ... frac = 0.10000
#   n_sig = 711.000 ... frac = 0.08000
#   n_sig = 714.000 ... frac = 0.04000
#   n_sig = 717.000 ... frac = 0.10000
#   n_sig = 720.000 ... frac = 0.08000
#   n_sig = 723.000 ... frac = 0.16000
#   n_sig = 726.000 ... frac = 0.08000
#   n_sig = 729.000 ... frac = 0.10000
#   n_sig = 732.000 ... frac = 0.04000
#   n_sig = 735.000 ... frac = 0.02000
#   n_sig = 738.000 ... frac = 0.08000
#   n_sig = 741.000 ... frac = 0.08000
#   n_sig = 744.000 ... frac = 0.12000
#   n_sig = 747.000 ... frac = 0.24000
#   n_sig = 750.000 ... frac = 0.08000
#   n_sig = 753.000 ... frac = 0.08000
#   n_sig = 756.000 ... frac = 0.14000
#   n_sig = 759.000 ... frac = 0.10000
#   n_sig = 762.000 ... frac = 0.12000
#   n_sig = 765.000 ... frac = 0.14000
#   n_sig = 768.000 ... frac = 0.08000
#   n_sig = 771.000 ... frac = 0.14000
#   n_sig = 774.000 ... frac = 0.26000
#   n_sig = 777.000 ... frac = 0.12000
#   n_sig = 780.000 ... frac = 0.10000
#   n_sig = 783.000 ... frac = 0.08000
#   n_sig = 786.000 ... frac = 0.10000
#   n_sig = 789.000 ... frac = 0.14000
#   n_sig = 792.000 ... frac = 0.12000
#   n_sig = 795.000 ... frac = 0.08000
#   n_sig = 798.000 ... frac = 0.20000
#   n_sig = 801.000 ... frac = 0.10000
#   n_sig = 804.000 ... frac = 0.16000
#   n_sig = 807.000 ... frac = 0.14000
#   n_sig = 810.000 ... frac = 0.20000
#   n_sig = 813.000 ... frac = 0.24000
#   n_sig = 816.000 ... frac = 0.16000
#   n_sig = 819.000 ... frac = 0.20000
#   n_sig = 822.000 ... frac = 0.08000
#   n_sig = 825.000 ... frac = 0.14000
#   n_sig = 828.000 ... frac = 0.24000
#   n_sig = 831.000 ... frac = 0.30000
#   n_sig = 834.000 ... frac = 0.14000
#   n_sig = 837.000 ... frac = 0.24000
#   n_sig = 840.000 ... frac = 0.20000
#   n_sig = 843.000 ... frac = 0.20000
#   n_sig = 846.000 ... frac = 0.34000
#   n_sig = 849.000 ... frac = 0.26000
#   n_sig = 852.000 ... frac = 0.24000
#   n_sig = 855.000 ... frac = 0.20000
#   n_sig = 858.000 ... frac = 0.26000
#   n_sig = 861.000 ... frac = 0.20000
#   n_sig = 864.000 ... frac = 0.16000
#   n_sig = 867.000 ... frac = 0.16000
#   n_sig = 870.000 ... frac = 0.18000
#   n_sig = 873.000 ... frac = 0.26000
#   n_sig = 876.000 ... frac = 0.18000
#   n_sig = 879.000 ... frac = 0.20000
#   n_sig = 882.000 ... frac = 0.18000
#   n_sig = 885.000 ... frac = 0.20000
#   n_sig = 888.000 ... frac = 0.22000
#   n_sig = 891.000 ... frac = 0.22000
#   n_sig = 894.000 ... frac = 0.24000
#   n_sig = 897.000 ... frac = 0.24000
#   n_sig = 900.000 ... frac = 0.16000
#   n_sig = 903.000 ... frac = 0.24000
#   n_sig = 906.000 ... frac = 0.24000
#   n_sig = 909.000 ... frac = 0.16000
#   n_sig = 912.000 ... frac = 0.22000
#   n_sig = 915.000 ... frac = 0.22000
#   n_sig = 918.000 ... frac = 0.20000
#   n_sig = 921.000 ... frac = 0.22000
#   n_sig = 924.000 ... frac = 0.12000
#   n_sig = 927.000 ... frac = 0.22000
#   n_sig = 930.000 ... frac = 0.24000
#   n_sig = 933.000 ... frac = 0.20000
#   n_sig = 936.000 ... frac = 0.24000
#   n_sig = 939.000 ... frac = 0.24000
#   n_sig = 942.000 ... frac = 0.26000
#   n_sig = 945.000 ... frac = 0.18000
#   n_sig = 948.000 ... frac = 0.34000
#   n_sig = 951.000 ... frac = 0.32000
#   n_sig = 954.000 ... frac = 0.22000
#   n_sig = 957.000 ... frac = 0.42000
#   n_sig = 960.000 ... frac = 0.26000
#   n_sig = 963.000 ... frac = 0.20000
#   n_sig = 966.000 ... frac = 0.34000
#   n_sig = 969.000 ... frac = 0.36000
#   n_sig = 972.000 ... frac = 0.42000
#   n_sig = 975.000 ... frac = 0.42000
#   n_sig = 978.000 ... frac = 0.34000
#   n_sig = 981.000 ... frac = 0.44000
#   n_sig = 984.000 ... frac = 0.30000
#   n_sig = 987.000 ... frac = 0.34000
#   n_sig = 990.000 ... frac = 0.26000
#   n_sig = 993.000 ... frac = 0.28000
#   n_sig = 996.000 ... frac = 0.38000
#   n_sig = 999.000 ... frac = 0.46000
#   n_sig = 1002.000 ... frac = 0.44000
#   n_sig = 1005.000 ... frac = 0.26000
#   n_sig = 1008.000 ... frac = 0.42000
#   n_sig = 1011.000 ... frac = 0.36000
#   n_sig = 1014.000 ... frac = 0.42000
#   n_sig = 1017.000 ... frac = 0.32000
#   n_sig = 1020.000 ... frac = 0.44000
#   n_sig = 1023.000 ... frac = 0.46000
#   n_sig = 1026.000 ... frac = 0.34000
#   n_sig = 1029.000 ... frac = 0.30000
#   n_sig = 1032.000 ... frac = 0.40000
#   n_sig = 1035.000 ... frac = 0.58000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00  414.00  828.00 1242.00 1656.00 2070.00  | n_sig (relative error)
# 500      |          0.0%    0.6%   18.0%   65.0%   94.8%   99.8%  |   1109.418 (+/-  1.4%) [spline]
# End time: 2019-02-26 11:33:29.659286
# Elapsed time: 0:07:44.462426

# %%
# sindec_array = np.linspace(-0.9,0.9,1)
# %time sens_0_test = [get_sens(ana7,ra=0,sindec=d,ext=0,llh_ext=0, cut_n_sigma=None, gamma=2, sigsub=False) for d in sindec_array]
# print(sens_0_test)
# %time sens_1_test = [get_sens(ana7,ra=0,sindec=d,ext=1,llh_ext=0, cut_n_sigma=None, gamma=2, sigsub=False) for d in sindec_array]
# print(sens_1_test)
# %time sens_2_test = [get_sens(ana7,ra=0,sindec=d,ext=2,llh_ext=0, cut_n_sigma=None, gamma=2, sigsub=False) for d in sindec_array]
# print(sens_2_test)
# #np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sindec_array.npy',dec_array)
# #np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/sindec_array.npy',dec_array)

# %%
disc_llhextNone = [disc_0_llhextNone,disc_1_llhextNone,disc_2_llhextNone,disc_3_llhextNone,disc_4_llhextNone,disc_5_llhextNone]
disc_llhext0 = [disc_0_llhext0,disc_1_llhext0,disc_2_llhext0,disc_3_llhext0,disc_4_llhext0,disc_5_llhext0]
extension_list = [0,1,2,3,4,5]

disc_llhextNone = np.array(disc_llhextNone)
disc_llhext0 = np.array(disc_llhext0)
extension_array = np.array(extension_list)

np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_llhextNone.npy',disc_llhextNone)
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_llhext0.npy',disc_llhext0)
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/extension_array.npy',extension_array)

# %%
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_0_test.npy',sens_0_test)

# %%
# %time sens_1 = [get_sens(ana7,ra=0,sindec=d,ext=1,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_1.npy',sens_1)
# %time disc_1 = [get_discovery(ana7,ra=0,sindec=d,ext=1,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_1.npy',disc_1)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:52:16.645193
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.279...
#   n_sig = 3.000 ... frac = 0.66000
#   n_sig = 6.000 ... frac = 0.88000
#   n_sig = 9.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    2.70    5.40    8.10   10.80   13.50  | n_sig (relative error)
# 500      |         50.4%   74.4%   85.2%   93.6%   97.0%   98.8%  |      6.757 (+/-  4.4%) [spline]
# 1000     |         49.3%   74.0%   85.1%   94.2%   97.3%   97.9%  |      6.664 (+/-  2.9%) [spline]
# End time: 2019-02-14 07:53:03.184730
# Elapsed time: 0:00:46.539537
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:53:07.618127
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.012...
#   n_sig = 3.000 ... frac = 0.86000
#   n_sig = 6.000 ... frac = 0.86000
#   n_sig = 9.000 ... frac = 0.92000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    2.70    5.40    8.10   10.80   13.50  | n_sig (relative error)
# 500      |         52.6%   66.2%   84.8%   91.4%   95.4%   98.0%  |      7.362 (+/-  7.7%) [spline]
# 1000     |         51.0%   67.9%   83.6%   92.1%   95.1%   98.2%  |      7.180 (+/-  4.3%) [spline]
# End time: 2019-02-14 07:53:56.520987
# Elapsed time: 0:00:48.902860
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:54:00.988983
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.221...
#   n_sig = 3.000 ... frac = 0.74000
#   n_sig = 6.000 ... frac = 0.80000
#   n_sig = 9.000 ... frac = 0.84000
#   n_sig = 12.000 ... frac = 0.90000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    3.60    7.20   10.80   14.40   18.00  | n_sig (relative error)
# 500      |         47.6%   68.0%   84.0%   92.2%   96.8%   99.2%  |      9.598 (+/-  5.8%) [spline]
# 1000     |         45.9%   67.4%   86.2%   92.4%   97.1%   99.3%  |      9.131 (+/-  4.5%) [spline]
# End time: 2019-02-14 07:54:52.803112
# Elapsed time: 0:00:51.814129
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:54:59.079763
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.298...
#   n_sig = 3.000 ... frac = 0.74000
#   n_sig = 6.000 ... frac = 0.84000
#   n_sig = 9.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    2.70    5.40    8.10   10.80   13.50  | n_sig (relative error)
# 500      |         54.2%   69.8%   86.2%   93.0%   97.6%   98.6%  |      6.702 (+/-  6.2%) [spline]
# 1000     |         51.6%   70.8%   85.1%   92.2%   97.4%   98.7%  |      7.126 (+/-  4.7%) [spline]
# End time: 2019-02-14 07:55:52.354220
# Elapsed time: 0:00:53.274457
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:55:58.128380
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.045...
#   n_sig = 3.000 ... frac = 0.70000
#   n_sig = 6.000 ... frac = 0.84000
#   n_sig = 9.000 ... frac = 0.94000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    2.70    5.40    8.10   10.80   13.50  | n_sig (relative error)
# 500      |         51.0%   64.6%   84.4%   91.0%   93.4%   98.2%  |      7.459 (+/- 10.0%) [spline]
# 1000     |         50.8%   66.9%   82.3%   90.0%   93.7%   97.8%  |      8.100 (+/-  6.6%) [spline]
# End time: 2019-02-14 07:56:57.252811
# Elapsed time: 0:00:59.124431
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:57:04.574426
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.157...
#   n_sig = 3.000 ... frac = 0.70000
#   n_sig = 6.000 ... frac = 0.86000
#   n_sig = 9.000 ... frac = 0.92000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    2.70    5.40    8.10   10.80   13.50  | n_sig (relative error)
# 500      |         49.4%   66.8%   76.6%   83.2%   88.6%   91.2%  |     11.968 (+/-  8.6%) [spline]
# 1000     |         49.8%   67.5%   76.2%   82.6%   89.8%   92.5%  |     10.938 (+/-  4.8%) [spline]
# End time: 2019-02-14 07:58:18.670943
# Elapsed time: 0:01:14.096517
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:58:25.670607
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.100...
#   n_sig = 3.000 ... frac = 0.78000
#   n_sig = 6.000 ... frac = 0.84000
#   n_sig = 9.000 ... frac = 0.88000
#   n_sig = 12.000 ... frac = 0.94000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    3.60    7.20   10.80   14.40   18.00  | n_sig (relative error)
# 500      |         52.4%   70.0%   82.8%   91.0%   96.6%   97.4%  |     10.274 (+/-  5.9%) [spline]
# 1000     |         53.8%   69.2%   81.5%   92.0%   95.8%   96.8%  |      9.859 (+/-  4.0%) [spline]
# End time: 2019-02-14 07:59:39.763747
# Elapsed time: 0:01:14.093140
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 07:59:45.269276
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.202...
#   n_sig = 3.000 ... frac = 0.66000
#   n_sig = 6.000 ... frac = 0.72000
#   n_sig = 9.000 ... frac = 0.86000
#   n_sig = 12.000 ... frac = 0.98000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    3.60    7.20   10.80   14.40   18.00  | n_sig (relative error)
# 500      |         49.8%   66.0%   81.4%   89.2%   93.2%   95.8%  |     11.373 (+/-  7.0%) [spline]
# 1000     |         49.2%   67.5%   80.9%   88.5%   93.7%   96.3%  |     11.689 (+/-  4.1%) [spline]
# End time: 2019-02-14 08:00:53.846195
# Elapsed time: 0:01:08.576919
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:00:59.338457
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.072...
#   n_sig = 3.000 ... frac = 0.60000
#   n_sig = 6.000 ... frac = 0.86000
#   n_sig = 9.000 ... frac = 0.86000
#   n_sig = 12.000 ... frac = 0.90000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    3.60    7.20   10.80   14.40   18.00  | n_sig (relative error)
# 500      |         53.2%   67.2%   77.4%   87.4%   93.4%   94.2%  |     12.018 (+/-  4.3%) [spline]
# 1000     |         52.3%   68.2%   78.6%   87.3%   92.7%   95.3%  |     12.349 (+/-  3.9%) [spline]
# End time: 2019-02-14 08:02:04.495273
# Elapsed time: 0:01:05.156816
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:02:11.075187
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.464...
#   n_sig = 3.000 ... frac = 0.64000
#   n_sig = 6.000 ... frac = 0.70000
#   n_sig = 9.000 ... frac = 0.88000
#   n_sig = 12.000 ... frac = 0.82000
#   n_sig = 15.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    4.50    9.00   13.50   18.00   22.50  | n_sig (relative error)
# 500      |         52.2%   66.6%   82.0%   89.6%   96.0%   96.4%  |     13.750 (+/-  6.6%) [spline]
# 1000     |         52.9%   69.1%   82.7%   90.8%   96.1%   97.1%  |     12.952 (+/-  3.9%) [spline]
# End time: 2019-02-14 08:03:18.910000
# Elapsed time: 0:01:07.834813
# CPU times: user 11.9 s, sys: 1min 19s, total: 1min 31s
# Wall time: 11min 7s
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:03:23.219078
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 45.888...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.04000
#   n_sig = 15.000 ... frac = 0.02000
#   n_sig = 18.000 ... frac = 0.08000
#   n_sig = 21.000 ... frac = 0.16000
#   n_sig = 24.000 ... frac = 0.20000
#   n_sig = 27.000 ... frac = 0.20000
#   n_sig = 30.000 ... frac = 0.34000
#   n_sig = 33.000 ... frac = 0.42000
#   n_sig = 36.000 ... frac = 0.66000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   10.80   21.60   32.40   43.20   54.00  | n_sig (relative error)
# 500      |          0.0%    0.6%    8.6%   47.0%   81.4%   95.0%  |     33.273 (+/-  2.1%) [spline]
# End time: 2019-02-14 08:04:00.495443
# Elapsed time: 0:00:37.276365
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:04:05.930638
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 39.844...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.02000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.10000
#   n_sig = 27.000 ... frac = 0.18000
#   n_sig = 30.000 ... frac = 0.24000
#   n_sig = 33.000 ... frac = 0.34000
#   n_sig = 36.000 ... frac = 0.48000
#   n_sig = 39.000 ... frac = 0.50000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   11.70   23.40   35.10   46.80   58.50  | n_sig (relative error)
# 500      |          0.0%    0.2%   12.0%   40.6%   77.6%   96.0%  |     38.093 (+/-  1.6%) [spline]
# End time: 2019-02-14 08:04:45.923452
# Elapsed time: 0:00:39.992814
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:04:51.474741
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 35.281...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.02000
#   n_sig = 21.000 ... frac = 0.04000
#   n_sig = 24.000 ... frac = 0.20000
#   n_sig = 27.000 ... frac = 0.20000
#   n_sig = 30.000 ... frac = 0.38000
#   n_sig = 33.000 ... frac = 0.48000
#   n_sig = 36.000 ... frac = 0.64000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   10.80   21.60   32.40   43.20   54.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    8.8%   38.0%   76.8%   96.2%  |     35.729 (+/-  1.4%) [spline]
# End time: 2019-02-14 08:05:32.823353
# Elapsed time: 0:00:41.348612
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:05:38.212728
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 36.885...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.04000
#   n_sig = 18.000 ... frac = 0.06000
#   n_sig = 21.000 ... frac = 0.16000
#   n_sig = 24.000 ... frac = 0.32000
#   n_sig = 27.000 ... frac = 0.38000
#   n_sig = 30.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    9.00   18.00   27.00   36.00   45.00  | n_sig (relative error)
# 500      |          0.0%    0.6%    7.0%   43.6%   78.4%   95.4%  |     28.552 (+/-  2.0%) [spline]
# End time: 2019-02-14 08:06:15.648661
# Elapsed time: 0:00:37.435933
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:06:20.976102
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 36.087...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.04000
#   n_sig = 18.000 ... frac = 0.04000
#   n_sig = 21.000 ... frac = 0.16000
#   n_sig = 24.000 ... frac = 0.12000
#   n_sig = 27.000 ... frac = 0.16000
#   n_sig = 30.000 ... frac = 0.32000
#   n_sig = 33.000 ... frac = 0.40000
#   n_sig = 36.000 ... frac = 0.34000
#   n_sig = 39.000 ... frac = 0.50000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   11.70   23.40   35.10   46.80   58.50  | n_sig (relative error)
# 500      |          0.0%    0.0%   10.8%   46.8%   86.2%   96.8%  |     36.046 (+/-  1.5%) [spline]
# End time: 2019-02-14 08:07:07.297794
# Elapsed time: 0:00:46.321692
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:07:13.828403
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 48.908...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.04000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.06000
#   n_sig = 36.000 ... frac = 0.08000
#   n_sig = 39.000 ... frac = 0.06000
#   n_sig = 42.000 ... frac = 0.10000
#   n_sig = 45.000 ... frac = 0.14000
#   n_sig = 48.000 ... frac = 0.22000
#   n_sig = 51.000 ... frac = 0.32000
#   n_sig = 54.000 ... frac = 0.48000
#   n_sig = 57.000 ... frac = 0.44000
#   n_sig = 60.000 ... frac = 0.62000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   18.00   36.00   54.00   72.00   90.00  | n_sig (relative error)
# 500      |          0.0%    0.2%    4.6%   44.0%   84.8%   98.0%  |     56.524 (+/-  1.3%) [spline]
# End time: 2019-02-14 08:08:16.474808
# Elapsed time: 0:01:02.646405
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:08:23.299041
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 45.484...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.04000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.02000
#   n_sig = 39.000 ... frac = 0.08000
#   n_sig = 42.000 ... frac = 0.12000
#   n_sig = 45.000 ... frac = 0.32000
#   n_sig = 48.000 ... frac = 0.50000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   14.40   28.80   43.20   57.60   72.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    0.6%   15.4%   56.4%   80.0%  |     55.061 (+/-  1.4%) [spline]
# End time: 2019-02-14 08:09:18.893167
# Elapsed time: 0:00:55.594126
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:09:25.203881
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 40.632...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.02000
#   n_sig = 36.000 ... frac = 0.06000
#   n_sig = 39.000 ... frac = 0.14000
#   n_sig = 42.000 ... frac = 0.10000
#   n_sig = 45.000 ... frac = 0.14000
#   n_sig = 48.000 ... frac = 0.20000
#   n_sig = 51.000 ... frac = 0.34000
#   n_sig = 54.000 ... frac = 0.32000
#   n_sig = 57.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   17.10   34.20   51.30   68.40   85.50  | n_sig (relative error)
# 500      |          0.0%    0.0%    6.4%   39.8%   79.6%   95.4%  |     55.550 (+/-  1.4%) [spline]
# End time: 2019-02-14 08:10:24.025570
# Elapsed time: 0:00:58.821689
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:10:31.022811
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 42.316...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.02000
#   n_sig = 36.000 ... frac = 0.06000
#   n_sig = 39.000 ... frac = 0.04000
#   n_sig = 42.000 ... frac = 0.10000
#   n_sig = 45.000 ... frac = 0.14000
#   n_sig = 48.000 ... frac = 0.24000
#   n_sig = 51.000 ... frac = 0.14000
#   n_sig = 54.000 ... frac = 0.46000
#   n_sig = 57.000 ... frac = 0.46000
#   n_sig = 60.000 ... frac = 0.60000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   18.00   36.00   54.00   72.00   90.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    6.0%   37.2%   79.2%   96.2%  |     59.396 (+/-  1.2%) [spline]
# End time: 2019-02-14 08:11:27.224289
# Elapsed time: 0:00:56.201478
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:11:32.845325
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 43.355...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.02000
#   n_sig = 33.000 ... frac = 0.02000
#   n_sig = 36.000 ... frac = 0.04000
#   n_sig = 39.000 ... frac = 0.06000
#   n_sig = 42.000 ... frac = 0.12000
#   n_sig = 45.000 ... frac = 0.20000
#   n_sig = 48.000 ... frac = 0.28000
#   n_sig = 51.000 ... frac = 0.34000
#   n_sig = 54.000 ... frac = 0.28000
#   n_sig = 57.000 ... frac = 0.42000
#   n_sig = 60.000 ... frac = 0.56000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   18.00   36.00   54.00   72.00   90.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    4.2%   28.0%   70.8%   95.0%  |     63.236 (+/-  1.0%) [spline]
# End time: 2019-02-14 08:12:31.331938
# Elapsed time: 0:00:58.486613
# CPU times: user 12.7 s, sys: 1min 45s, total: 1min 57s
# Wall time: 9min 12s

# %%
# %time sens_2 = [get_sens(ana7,ra=0,sindec=d,ext=2,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_2.npy',sens_2)
# %time disc_2 = [get_discovery(ana7,ra=0,sindec=d,ext=2,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_2.npy',disc_2)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:14:05.949265
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.429...
#   n_sig = 3.000 ... frac = 0.56000
#   n_sig = 6.000 ... frac = 0.84000
#   n_sig = 9.000 ... frac = 0.80000
#   n_sig = 12.000 ... frac = 0.88000
#   n_sig = 15.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    4.50    9.00   13.50   18.00   22.50  | n_sig (relative error)
# 500      |         53.8%   74.2%   88.6%   95.2%   97.8%   99.0%  |      9.723 (+/-  6.1%) [spline]
# 1000     |         49.0%   72.2%   87.5%   94.5%   97.3%   99.4%  |     10.256 (+/-  4.0%) [spline]
# End time: 2019-02-14 08:15:15.411862
# Elapsed time: 0:01:09.462597
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:15:22.186164
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.011...
#   n_sig = 3.000 ... frac = 0.70000
#   n_sig = 6.000 ... frac = 0.78000
#   n_sig = 9.000 ... frac = 0.84000
#   n_sig = 12.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    3.60    7.20   10.80   14.40   18.00  | n_sig (relative error)
# 500      |         45.0%   67.6%   80.0%   88.2%   93.6%   96.2%  |     11.820 (+/-  6.2%) [spline]
# 1000     |         47.9%   68.1%   81.3%   88.3%   94.5%   95.6%  |     11.650 (+/-  3.7%) [spline]
# End time: 2019-02-14 08:16:29.719474
# Elapsed time: 0:01:07.533310
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:16:36.286127
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.118...
#   n_sig = 3.000 ... frac = 0.66000
#   n_sig = 6.000 ... frac = 0.76000
#   n_sig = 9.000 ... frac = 0.80000
#   n_sig = 12.000 ... frac = 0.82000
#   n_sig = 15.000 ... frac = 0.94000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    4.50    9.00   13.50   18.00   22.50  | n_sig (relative error)
# 500      |         46.8%   67.4%   82.2%   89.6%   96.4%   97.4%  |     13.746 (+/-  5.2%) [spline]
# 1000     |         48.6%   65.7%   82.6%   88.9%   95.7%   97.3%  |     14.191 (+/-  4.5%) [spline]
# End time: 2019-02-14 08:17:53.537560
# Elapsed time: 0:01:17.251433
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:18:01.221406
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.026...
#   n_sig = 3.000 ... frac = 0.82000
#   n_sig = 6.000 ... frac = 0.76000
#   n_sig = 9.000 ... frac = 0.86000
#   n_sig = 12.000 ... frac = 0.98000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    3.60    7.20   10.80   14.40   18.00  | n_sig (relative error)
# 500      |         52.2%   70.4%   85.6%   94.0%   95.2%   98.0%  |      8.671 (+/-  4.2%) [spline]
# 1000     |         52.6%   69.3%   84.3%   93.3%   95.1%   97.8%  |      9.062 (+/-  3.4%) [spline]
# End time: 2019-02-14 08:19:23.245207
# Elapsed time: 0:01:22.023801
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:19:31.138509
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.000...
#   n_sig = 3.000 ... frac = 0.52000
#   n_sig = 6.000 ... frac = 0.68000
#   n_sig = 9.000 ... frac = 0.82000
#   n_sig = 12.000 ... frac = 0.84000
#   n_sig = 15.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    4.50    9.00   13.50   18.00   22.50  | n_sig (relative error)
# 500      |         43.4%   66.0%   79.8%   91.8%   94.4%   96.6%  |     12.408 (+/-  4.6%) [spline]
# 1000     |         44.7%   65.0%   79.4%   91.3%   94.8%   96.8%  |     12.703 (+/-  3.3%) [spline]
# End time: 2019-02-14 08:21:00.163320
# Elapsed time: 0:01:29.024811
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:21:09.651391
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.203...
#   n_sig = 3.000 ... frac = 0.58000
#   n_sig = 6.000 ... frac = 0.72000
#   n_sig = 9.000 ... frac = 0.68000
#   n_sig = 12.000 ... frac = 0.72000
#   n_sig = 15.000 ... frac = 0.82000
#   n_sig = 18.000 ... frac = 0.84000
#   n_sig = 21.000 ... frac = 0.92000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    6.30   12.60   18.90   25.20   31.50  | n_sig (relative error)
# 500      |         48.2%   60.8%   73.6%   86.8%   94.2%   97.6%  |     21.169 (+/-  4.1%) [spline]
# 1000     |         45.4%   62.2%   76.6%   87.1%   94.3%   96.8%  |     21.032 (+/-  3.0%) [spline]
# End time: 2019-02-14 08:23:04.301587
# Elapsed time: 0:01:54.650196
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:23:12.904675
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.143...
#   n_sig = 3.000 ... frac = 0.56000
#   n_sig = 6.000 ... frac = 0.58000
#   n_sig = 9.000 ... frac = 0.60000
#   n_sig = 12.000 ... frac = 0.76000
#   n_sig = 15.000 ... frac = 0.86000
#   n_sig = 18.000 ... frac = 0.90000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    5.40   10.80   16.20   21.60   27.00  | n_sig (relative error)
# 500      |         49.0%   66.8%   73.2%   84.2%   89.4%   95.2%  |     22.187 (+/-  6.3%) [spline]
# 1000     |         48.1%   64.2%   74.4%   86.0%   89.0%   95.3%  |     22.763 (+/-  4.2%) [spline]
# End time: 2019-02-14 08:24:53.393525
# Elapsed time: 0:01:40.488850
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:25:01.521589
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.151...
#   n_sig = 3.000 ... frac = 0.62000
#   n_sig = 6.000 ... frac = 0.62000
#   n_sig = 9.000 ... frac = 0.76000
#   n_sig = 12.000 ... frac = 0.68000
#   n_sig = 15.000 ... frac = 0.78000
#   n_sig = 18.000 ... frac = 0.80000
#   n_sig = 21.000 ... frac = 0.84000
#   n_sig = 24.000 ... frac = 0.96000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    7.20   14.40   21.60   28.80   36.00  | n_sig (relative error)
# 500      |         47.0%   65.2%   84.4%   89.2%   97.4%   97.8%  |     22.396 (+/-  5.7%) [spline]
# 1000     |         46.5%   65.3%   83.7%   90.3%   96.5%   98.3%  |     21.256 (+/-  4.9%) [spline]
# End time: 2019-02-14 08:26:38.893459
# Elapsed time: 0:01:37.371870
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:26:46.892115
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 0.043...
#   n_sig = 3.000 ... frac = 0.48000
#   n_sig = 6.000 ... frac = 0.76000
#   n_sig = 9.000 ... frac = 0.70000
#   n_sig = 12.000 ... frac = 0.76000
#   n_sig = 15.000 ... frac = 0.86000
#   n_sig = 18.000 ... frac = 0.86000
#   n_sig = 21.000 ... frac = 0.90000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    6.30   12.60   18.90   25.20   31.50  | n_sig (relative error)
# 500      |         49.8%   70.4%   81.4%   91.6%   93.6%   98.4%  |     17.302 (+/-  6.1%) [spline]
# 1000     |         53.0%   69.9%   82.8%   91.0%   94.8%   98.1%  |     17.827 (+/-  4.3%) [spline]
# End time: 2019-02-14 08:28:18.597382
# Elapsed time: 0:01:31.705267
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:28:26.388426
# Using 15 cores.
# * Starting initial scan for 90% of 50 trials with TS >= 1.194...
#   n_sig = 3.000 ... frac = 0.48000
#   n_sig = 6.000 ... frac = 0.62000
#   n_sig = 9.000 ... frac = 0.60000
#   n_sig = 12.000 ... frac = 0.72000
#   n_sig = 15.000 ... frac = 0.72000
#   n_sig = 18.000 ... frac = 0.74000
#   n_sig = 21.000 ... frac = 0.80000
#   n_sig = 24.000 ... frac = 0.76000
#   n_sig = 27.000 ... frac = 0.90000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00    8.10   16.20   24.30   32.40   40.50  | n_sig (relative error)
# 500      |         44.6%   62.2%   77.8%   89.2%   91.6%   97.4%  |     26.416 (+/- 14.2%) [spline]
# 1000     |         47.2%   60.9%   75.4%   87.3%   91.7%   96.6%  |     28.942 (+/-  6.0%) [spline]
# End time: 2019-02-14 08:30:01.211798
# Elapsed time: 0:01:34.823372
# CPU times: user 12.9 s, sys: 1min 46s, total: 1min 59s
# Wall time: 16min
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:30:08.092948
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 50.126...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.04000
#   n_sig = 36.000 ... frac = 0.12000
#   n_sig = 39.000 ... frac = 0.12000
#   n_sig = 42.000 ... frac = 0.26000
#   n_sig = 45.000 ... frac = 0.20000
#   n_sig = 48.000 ... frac = 0.18000
#   n_sig = 51.000 ... frac = 0.32000
#   n_sig = 54.000 ... frac = 0.48000
#   n_sig = 57.000 ... frac = 0.46000
#   n_sig = 60.000 ... frac = 0.66000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   18.00   36.00   54.00   72.00   90.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    9.8%   44.0%   90.0%   99.4%  |     56.428 (+/-  1.4%) [spline]
# End time: 2019-02-14 08:31:09.174550
# Elapsed time: 0:01:01.081602
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:31:15.837077
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 33.654...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.02000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.02000
#   n_sig = 27.000 ... frac = 0.10000
#   n_sig = 30.000 ... frac = 0.16000
#   n_sig = 33.000 ... frac = 0.18000
#   n_sig = 36.000 ... frac = 0.20000
#   n_sig = 39.000 ... frac = 0.38000
#   n_sig = 42.000 ... frac = 0.28000
#   n_sig = 45.000 ... frac = 0.40000
#   n_sig = 48.000 ... frac = 0.64000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   14.40   28.80   43.20   57.60   72.00  | n_sig (relative error)
# 500      |          0.0%    0.4%    5.6%   23.4%   65.8%   89.8%  |     52.171 (+/-  1.0%) [spline]
# End time: 2019-02-14 08:32:15.760131
# Elapsed time: 0:00:59.923054
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:32:22.441355
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 38.745...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.02000
#   n_sig = 33.000 ... frac = 0.06000
#   n_sig = 36.000 ... frac = 0.06000
#   n_sig = 39.000 ... frac = 0.06000
#   n_sig = 42.000 ... frac = 0.06000
#   n_sig = 45.000 ... frac = 0.16000
#   n_sig = 48.000 ... frac = 0.22000
#   n_sig = 51.000 ... frac = 0.34000
#   n_sig = 54.000 ... frac = 0.38000
#   n_sig = 57.000 ... frac = 0.58000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   17.10   34.20   51.30   68.40   85.50  | n_sig (relative error)
# 500      |          0.0%    0.0%    4.0%   29.8%   70.6%   92.4%  |     59.628 (+/-  0.9%) [spline]
# End time: 2019-02-14 08:33:44.030034
# Elapsed time: 0:01:21.588679
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:33:54.471962
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 37.709...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.02000
#   n_sig = 18.000 ... frac = 0.02000
#   n_sig = 21.000 ... frac = 0.08000
#   n_sig = 24.000 ... frac = 0.10000
#   n_sig = 27.000 ... frac = 0.04000
#   n_sig = 30.000 ... frac = 0.16000
#   n_sig = 33.000 ... frac = 0.14000
#   n_sig = 36.000 ... frac = 0.16000
#   n_sig = 39.000 ... frac = 0.34000
#   n_sig = 42.000 ... frac = 0.22000
#   n_sig = 45.000 ... frac = 0.32000
#   n_sig = 48.000 ... frac = 0.42000
#   n_sig = 51.000 ... frac = 0.48000
#   n_sig = 54.000 ... frac = 0.70000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   16.20   32.40   48.60   64.80   81.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    8.8%   49.0%   87.0%   98.6%  |     49.010 (+/-  1.5%) [spline]
# End time: 2019-02-14 08:35:33.116384
# Elapsed time: 0:01:38.644422
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:35:43.918968
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 25.713...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.02000
#   n_sig = 33.000 ... frac = 0.06000
#   n_sig = 36.000 ... frac = 0.12000
#   n_sig = 39.000 ... frac = 0.10000
#   n_sig = 42.000 ... frac = 0.32000
#   n_sig = 45.000 ... frac = 0.30000
#   n_sig = 48.000 ... frac = 0.42000
#   n_sig = 51.000 ... frac = 0.62000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   15.30   30.60   45.90   61.20   76.50  | n_sig (relative error)
# 500      |          0.0%    0.0%    6.2%   33.0%   75.8%   95.4%  |     51.948 (+/-  1.0%) [spline]
# End time: 2019-02-14 08:37:33.372071
# Elapsed time: 0:01:49.453103
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:37:48.135734
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 40.083...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.02000
#   n_sig = 51.000 ... frac = 0.02000
#   n_sig = 54.000 ... frac = 0.04000
#   n_sig = 57.000 ... frac = 0.04000
#   n_sig = 60.000 ... frac = 0.08000
#   n_sig = 63.000 ... frac = 0.06000
#   n_sig = 66.000 ... frac = 0.12000
#   n_sig = 69.000 ... frac = 0.16000
#   n_sig = 72.000 ... frac = 0.16000
#   n_sig = 75.000 ... frac = 0.32000
#   n_sig = 78.000 ... frac = 0.22000
#   n_sig = 81.000 ... frac = 0.48000
#   n_sig = 84.000 ... frac = 0.52000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   25.20   50.40   75.60  100.80  126.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    3.2%   30.6%   78.0%   96.8%  |     85.816 (+/-  1.0%) [spline]
# End time: 2019-02-14 08:40:14.780960
# Elapsed time: 0:02:26.645226
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:40:23.450359
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 38.481...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.02000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.02000
#   n_sig = 60.000 ... frac = 0.04000
#   n_sig = 63.000 ... frac = 0.14000
#   n_sig = 66.000 ... frac = 0.06000
#   n_sig = 69.000 ... frac = 0.08000
#   n_sig = 72.000 ... frac = 0.16000
#   n_sig = 75.000 ... frac = 0.24000
#   n_sig = 78.000 ... frac = 0.38000
#   n_sig = 81.000 ... frac = 0.22000
#   n_sig = 84.000 ... frac = 0.36000
#   n_sig = 87.000 ... frac = 0.40000
#   n_sig = 90.000 ... frac = 0.34000
#   n_sig = 93.000 ... frac = 0.44000
#   n_sig = 96.000 ... frac = 0.54000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   28.80   57.60   86.40  115.20  144.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    7.8%   48.4%   86.0%   99.8%  |     87.564 (+/-  1.4%) [spline]
# End time: 2019-02-14 08:42:09.194139
# Elapsed time: 0:01:45.743780
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:42:17.019514
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 40.754...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.02000
#   n_sig = 48.000 ... frac = 0.02000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.02000
#   n_sig = 57.000 ... frac = 0.04000
#   n_sig = 60.000 ... frac = 0.10000
#   n_sig = 63.000 ... frac = 0.04000
#   n_sig = 66.000 ... frac = 0.06000
#   n_sig = 69.000 ... frac = 0.14000
#   n_sig = 72.000 ... frac = 0.20000
#   n_sig = 75.000 ... frac = 0.26000
#   n_sig = 78.000 ... frac = 0.38000
#   n_sig = 81.000 ... frac = 0.42000
#   n_sig = 84.000 ... frac = 0.44000
#   n_sig = 87.000 ... frac = 0.42000
#   n_sig = 90.000 ... frac = 0.52000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   27.00   54.00   81.00  108.00  135.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    3.4%   33.4%   77.6%   97.0%  |     90.991 (+/-  1.2%) [spline]
# End time: 2019-02-14 08:43:46.186138
# Elapsed time: 0:01:29.166624
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:43:54.624055
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 35.210...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.02000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.02000
#   n_sig = 39.000 ... frac = 0.06000
#   n_sig = 42.000 ... frac = 0.08000
#   n_sig = 45.000 ... frac = 0.08000
#   n_sig = 48.000 ... frac = 0.08000
#   n_sig = 51.000 ... frac = 0.16000
#   n_sig = 54.000 ... frac = 0.08000
#   n_sig = 57.000 ... frac = 0.18000
#   n_sig = 60.000 ... frac = 0.10000
#   n_sig = 63.000 ... frac = 0.18000
#   n_sig = 66.000 ... frac = 0.28000
#   n_sig = 69.000 ... frac = 0.20000
#   n_sig = 72.000 ... frac = 0.34000
#   n_sig = 75.000 ... frac = 0.24000
#   n_sig = 78.000 ... frac = 0.48000
#   n_sig = 81.000 ... frac = 0.66000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   24.30   48.60   72.90   97.20  121.50  | n_sig (relative error)
# 500      |          0.0%    0.0%    3.6%   27.8%   69.8%   91.0%  |     85.495 (+/-  1.0%) [spline]
# End time: 2019-02-14 08:45:14.633735
# Elapsed time: 0:01:20.009680
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 08:45:22.280163
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 66.401...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.00000
#   n_sig = 48.000 ... frac = 0.00000
#   n_sig = 51.000 ... frac = 0.00000
#   n_sig = 54.000 ... frac = 0.00000
#   n_sig = 57.000 ... frac = 0.00000
#   n_sig = 60.000 ... frac = 0.00000
#   n_sig = 63.000 ... frac = 0.00000
#   n_sig = 66.000 ... frac = 0.00000
#   n_sig = 69.000 ... frac = 0.00000
#   n_sig = 72.000 ... frac = 0.00000
#   n_sig = 75.000 ... frac = 0.04000
#   n_sig = 78.000 ... frac = 0.04000
#   n_sig = 81.000 ... frac = 0.00000
#   n_sig = 84.000 ... frac = 0.04000
#   n_sig = 87.000 ... frac = 0.04000
#   n_sig = 90.000 ... frac = 0.08000
#   n_sig = 93.000 ... frac = 0.06000
#   n_sig = 96.000 ... frac = 0.08000
#   n_sig = 99.000 ... frac = 0.10000
#   n_sig = 102.000 ... frac = 0.16000
#   n_sig = 105.000 ... frac = 0.04000
#   n_sig = 108.000 ... frac = 0.24000
#   n_sig = 111.000 ... frac = 0.12000
#   n_sig = 114.000 ... frac = 0.38000
#   n_sig = 117.000 ... frac = 0.30000
#   n_sig = 120.000 ... frac = 0.30000
#   n_sig = 123.000 ... frac = 0.42000
#   n_sig = 126.000 ... frac = 0.44000
#   n_sig = 129.000 ... frac = 0.52000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   38.70   77.40  116.10  154.80  193.50  | n_sig (relative error)
# 500      |          0.0%    0.0%    1.4%   27.8%   79.4%   97.8%  |    132.592 (+/-  0.8%) [spline]
# End time: 2019-02-14 08:47:34.610463
# Elapsed time: 0:02:12.330300
# CPU times: user 16.1 s, sys: 3min 21s, total: 3min 37s
# Wall time: 17min 33s

# %%
#%time sens_3 = [get_sens(ana7,ra=0,sindec=d,ext=3,gamma=2) for d in dec_array]
#np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_3.npy',sens_3)
# %time disc_3 = [get_discovery(ana7,ra=0,sindec=d,ext=3,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_3.npy',disc_3)
# Out:
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 09:41:06.971045
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 52.208...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.00000
#   n_sig = 33.000 ... frac = 0.00000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.06000
#   n_sig = 42.000 ... frac = 0.00000
#   n_sig = 45.000 ... frac = 0.10000
#   n_sig = 48.000 ... frac = 0.12000
#   n_sig = 51.000 ... frac = 0.14000
#   n_sig = 54.000 ... frac = 0.36000
#   n_sig = 57.000 ... frac = 0.38000
#   n_sig = 60.000 ... frac = 0.30000
#   n_sig = 63.000 ... frac = 0.44000
#   n_sig = 66.000 ... frac = 0.52000
# * Generating batches of 500 trials...
# n_trials | n_inj    0.00   19.80   39.60   59.40   79.20   99.00  | n_sig (relative error)
# 500      |          0.0%    0.0%    2.6%   30.8%   70.4%   94.2%  |     68.847 (+/-  1.1%) [spline]
# End time: 2019-02-14 09:42:56.238887
# Elapsed time: 0:01:49.267842
# Performing 500 background trials using 15 cores:
#         500/500 trials complete.
# Start time: 2019-02-14 09:43:06.596962
# Using 15 cores.
# * Starting initial scan for 50% of 50 trials with TS >= 37.768...
#   n_sig = 3.000 ... frac = 0.00000
#   n_sig = 6.000 ... frac = 0.00000
#   n_sig = 9.000 ... frac = 0.00000
#   n_sig = 12.000 ... frac = 0.00000
#   n_sig = 15.000 ... frac = 0.00000
#   n_sig = 18.000 ... frac = 0.00000
#   n_sig = 21.000 ... frac = 0.00000
#   n_sig = 24.000 ... frac = 0.00000
#   n_sig = 27.000 ... frac = 0.00000
#   n_sig = 30.000 ... frac = 0.02000
#   n_sig = 33.000 ... frac = 0.04000
#   n_sig = 36.000 ... frac = 0.00000
#   n_sig = 39.000 ... frac = 0.00000
#   n_sig = 42.000 ... frac = 0.04000
#   n_sig = 45.000 ... frac = 0.02000
#   n_sig = 48.000 ... frac = 0.04000
#   n_sig = 51.000 ... frac = 0.04000
#   n_sig = 54.000 ... frac = 0.14000
#   n_sig = 57.000 ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-c9defdae84d6> in <module>()
#       1 #%time sens_3 = [get_sens(ana7,ra=0,sindec=d,ext=3,gamma=2) for d in dec_array]
#       2 #np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_3.npy',sens_3)
# ----> 3 get_ipython().magic(u'time disc_3 = [get_discovery(ana7,ra=0,sindec=d,ext=3,gamma=2) for d in dec_array]')
#       4 np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_3.npy',disc_3)
#
# /cvmfs/icecube.opensciencegrid.org/py2-v3.0.1/RHEL_7_x86_64/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /cvmfs/icecube.opensciencegrid.org/py2-v3.0.1/RHEL_7_x86_64/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /cvmfs/icecube.opensciencegrid.org/py2-v3.0.1/RHEL_7_x86_64/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /cvmfs/icecube.opensciencegrid.org/py2-v3.0.1/RHEL_7_x86_64/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1183         else:
#    1184             st = clock2()
# -> 1185             exec(code, glob, local_ns)
#    1186             end = clock2()
#    1187             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-12-e833d40dacea> in get_discovery(ana, ra, sindec, ext, gamma, batch_size)
#      22     tr = get_tr(src, ana)#, flux=flux)
#      23     bg = cy.dists.Chi2TSD(tr.get_many_fits(500))
# ---> 24     sens = tr.find_n_sig(bg.isf_nsigma(5,fit=True),0.5,batch_size=batch_size,max_batch_size=1000,tol=0.03)
#      25     sens['flux'] = tr.to_E2dNdE(sens['n_sig'], E0=100, unit=1e3)
#      26     return sens['flux']
#
# /mnt/lfs3/user/drysewyk/software/external/csky/csky/trial.pyc in find_n_sig(self, ts, beta, tol, n_batches, batch_size, coverage, n_sig_step, n_sig_start, first_batch_size, min_batch_size, max_batch_size, tss, mp_cpus, seed, logging)
#     278                     first_batch_size, n_sig, poisson=True, logging=False,
#     279                     seed=random.randint (2**32),
# --> 280                     mp_cpus=min (mp_cpus, int (np.ceil (first_batch_size / 2)))).ts
#     281                 count_initial_batches += 1
#     282                 count_initial_trials += first_batch_size
#
# /mnt/lfs3/user/drysewyk/software/external/csky/csky/trial.pyc in get_many_fits(self, n_trials, n_sig, poisson, seed, mp_cpus, logging)
#     204                 for i in xrange (n_jobs)]
#     205             for proc in procs:
# --> 206                 proc.start ()
#     207             # monitor progress, try to catch interrupts
#     208             try:
#
# /cvmfs/icecube.opensciencegrid.org/py2-v3.0.1/RHEL_7_x86_64/lib/python2.7/multiprocessing/process.pyc in start(self)
#     128         else:
#     129             from .forking import Popen
# --> 130         self._popen = Popen(self)
#     131         _current_process._children.add(self)
#     132
#
# /cvmfs/icecube.opensciencegrid.org/py2-v3.0.1/RHEL_7_x86_64/lib/python2.7/multiprocessing/forking.pyc in __init__(self, process_obj)
#     119             self.returncode = None
#     120
# --> 121             self.pid = os.fork()
#     122             if self.pid == 0:
#     123                 if 'random' in sys.modules:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
# %time sens_4 = [get_sens(ana7,ra=0,sindec=d,ext=4,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_4.npy',sens_4)
# %time disc_4 = [get_discovery(ana7,ra=0,sindec=d,ext=4,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_4.npy',disc_4)

# %%
# %time sens_5 = [get_sens(ana7,ra=0,sindec=d,ext=5,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_5.npy',sens_5)
# %time disc_5 = [get_discovery(ana7,ra=0,sindec=d,ext=5,gamma=2) for d in dec_array]
np.save('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_5.npy',disc_5)
