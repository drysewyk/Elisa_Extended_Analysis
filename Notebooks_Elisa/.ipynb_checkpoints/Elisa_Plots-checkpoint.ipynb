# %%
from __future__ import print_function
from csky.ipyconfig import *
from csky import bk, analysis, coord, dists, hyp, inj, llh, pdf, selections, trial, utils
import csky as cy
import histlite as hl
import healpy as hp
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt
#from icecube import astro

mp_cpus = 15
mrichman_mpl()

# %%
sindec_30 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sindec_array_30bins.npy')
sindec_50 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sindec_array_50bins.npy')
sindec_49 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sindec_array_50bins_endpointFalse.npy')


sens_0 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_0ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
sens_0_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_0ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_50bins.npy')
sens_1 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_1ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
sens_1_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_1ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_50bins.npy')
sens_2 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_2ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
sens_2_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_2ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_50bins.npy')
sens_3 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_3ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
sens_3_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_3ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_50bins.npy')
sens_4 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_4ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
sens_4_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_4ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_50bins.npy')
sens_5 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_5ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
sens_5_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/Sensitivity/sens_5ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_50bins.npy')

disc_0 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_0ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
disc_0_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_0ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_30bins.npy')
disc_1 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_1ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
disc_1_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_1ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_30bins.npy')
disc_2 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_2ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
disc_2_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_2ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_30bins.npy')
disc_3 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_3ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
disc_3_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_3ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_30bins.npy')
disc_4 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_4ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
disc_4_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_4ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_30bins.npy')
disc_5 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_5ext_llhextNone_cutnsigNone_gamma2_sigsubFalse_50bins.npy')
disc_5_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_5ext_llhextNone_cutnsigNone_gamma2_sigsubTrue_30bins.npy')

disc_llhextNone = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_llhextNone_sigsubFalse.npy')
disc_llhextNone_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_llhextNone_sigsubTrue.npy')
disc_llhext0 = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_llhext0_sigsubFalse.npy')
disc_llhext0_ss = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/disc_llhext0_sigsubTrue.npy')
extension_array = np.load('/data/user/drysewyk/llh_sandbox/NumPyArrays/DiscoveryPotential/extension_array.npy')

# %%
repo = selections.mrichman_repo

fig, ax = plt.subplots ()
plt.semilogy(sindec_50,sens_0,label=r'csky',color='blue')
plt.semilogy(sindec_50,sens_0_ss,label=r'csky SS', color='blue',linestyle='--')
sd,phi = repo.get_performance('sens_E200_ps7yr')[:2]
plt.semilogy(sd,phi,color='r',label=r'official')
plt.legend(loc='lower left',fontsize=11.5)
ax.tick_params(axis='both',which='major',length=8,labelsize=10)
ax.tick_params(axis='both',which='minor',length=4)
plt.title(r'Extension=${0}^{\circ}$')
plt.xlabel(r'$\sin (\delta)$', fontsize=14)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=14)
# Out:
# Reading /data/user/mrichman/data/analyses/performance/sens_E200_ps7yr.tuple.npy ...

# %%
fig, ax = plt.subplots ()
#plt.semilogy(testdec,test,label=r'test',color='green')
plt.semilogy(extension_array,disc_llhextNone,label=r'Extended source llh',color='r')
plt.semilogy(extension_array,disc_llhext0,label=r'Point source llh', color='r',linestyle='--')
plt.semilogy(extension_array,disc_llhextNone_ss,label=r'Extended source llh ss',color='blue')
plt.semilogy(extension_array,disc_llhext0_ss,label=r'Point source llh ss', color='blue',linestyle='--')
plt.legend(loc='lower right',fontsize=11.5)
ax.tick_params(axis='both',which='major',length=8,labelsize=10)
ax.tick_params(axis='both',which='minor',length=4)
plt.xlabel(r'source extension $[{}^{\circ}]$', fontsize=14)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=14)

# %%
fig, ax = plt.subplots ()
#plt.semilogy(testdec,test,label=r'test',color='green')

plt.plot(extension_array,disc_llhextNone_ss,label=r'Extended source llh',color='blue')
plt.plot(extension_array,disc_llhext0_ss,label=r'Point source llh', color='blue',linestyle='--')
plt.legend(loc='upper left',fontsize=11.5)
ax.tick_params(axis='both',which='major',length=8,labelsize=10)
ax.tick_params(axis='both',which='minor',length=4)
plt.xlabel(r'source extension $[{}^{\circ}]$', fontsize=14)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=14)

# %%
fig, ax = plt.subplots ()
plt.semilogy(sindec_50,sens_1,label=r'$\sigma_{src,llh}=1^{\circ}$', color='orangered', linestyle='-')
plt.semilogy(sindec_50,sens_2,label=r'$\sigma_{src,llh}=2^{\circ}$', color='slateblue')
plt.semilogy(sindec_50,sens_3,label=r'$\sigma_{src,llh}=3^{\circ}$', color='deeppink')
plt.semilogy(sindec_50,sens_4,label=r'$\sigma_{src,llh}=4^{\circ}$', color='forestgreen')
plt.semilogy(sindec_49,sens_5,label=r'$\sigma_{src,llh}=5^{\circ}$', color='goldenrod')

#box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fancybox=True, shadow=True, ncol=1, fontsize=11.5)

plt.grid(which='both')
plt.xlim(-1,1)
plt.ylim(4*10**(-13),9*10**(-11))
plt.legend(loc='lower left',fontsize=13.5,fancybox=True)
plt.title('Sensitivity without signal subtraction',fontsize=18)
ax.tick_params(axis='both',which='major',length=8,labelsize=14)
ax.tick_params(axis='both',which='minor',length=4)
plt.xlabel(r'$\sin (\delta)$', fontsize=18)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=18)
fig.set_size_inches(7,4.5)

# %%
fig, ax = plt.subplots ()
plt.semilogy(sindec_50,sens_1_ss,label=r'$\sigma_{src,llh}}=1^{\circ}$', color='orangered', linestyle='-')
plt.semilogy(sindec_50,sens_2_ss,label=r'$\sigma_{src,llh}=2^{\circ}$', color='slateblue', linestyle='-')
plt.semilogy(sindec_50,sens_3_ss,label=r'$\sigma_{src,llh}=3^{\circ}$', color='deeppink', linestyle='-')
plt.semilogy(sindec_50,sens_4_ss,label=r'$\sigma_{src,llh}=4^{\circ}$', color='forestgreen', linestyle='-')
plt.semilogy(sindec_50,sens_5_ss,label=r'$\sigma_{src,llh}=5^{\circ}$', color='goldenrod', linestyle='-')

#box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fancybox=True, shadow=True, ncol=1, fontsize=11.5)

plt.grid(which='both')
plt.xlim(-1,1)
plt.ylim(4*10**(-13),9*10**(-11))
plt.legend(loc='lower left',fontsize=13.5,fancybox=True)
plt.title('Sensitivity with signal subtraction',fontsize=18)
ax.tick_params(axis='both',which='major',length=8,labelsize=14)
ax.tick_params(axis='both',which='minor',length=4)
plt.xlabel(r'$\sin (\delta)$', fontsize=18)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=18)
fig.set_size_inches(7,4.5)

# %%
fig, ax = plt.subplots ()
plt.semilogy(sindec_50,disc_1,label=r'$\sigma_{src,llh}=1^{\circ}$', color='orangered', linestyle='-')
plt.semilogy(sindec_50,disc_2,label=r'$\sigma_{src,llh}=2^{\circ}$', color='slateblue')
plt.semilogy(sindec_50,disc_3,label=r'$\sigma_{src,llh}=3^{\circ}$', color='deeppink')
plt.semilogy(sindec_50,disc_4,label=r'$\sigma_{src,llh}=4^{\circ}$', color='forestgreen')
plt.semilogy(sindec_50,disc_5,label=r'$\sigma_{src,llh}=5^{\circ}$', color='goldenrod')

#box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fancybox=True, shadow=True, ncol=1, fontsize=11.5)

plt.grid(which='both')
plt.xlim(-1,1)
plt.ylim(10**(-12),3*10**(-10))
plt.legend(loc='lower left',fontsize=13.5,fancybox=True)
plt.title('Discovery Potential without signal subtraction',fontsize=18)
ax.tick_params(axis='both',which='major',length=8,labelsize=14)
ax.tick_params(axis='both',which='minor',length=4)
plt.xlabel(r'$\sin (\delta)$', fontsize=18)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=18)
fig.set_size_inches(7,4.5)

# %%
fig, ax = plt.subplots ()
plt.semilogy(sindec_30,disc_1_ss,label=r'$\sigma_{src,llh}=1^{\circ}$', color='orangered', linestyle='-')
plt.semilogy(sindec_30,disc_2_ss,label=r'$\sigma_{src,llh}=2^{\circ}$', color='slateblue')
plt.semilogy(sindec_30,disc_3_ss,label=r'$\sigma_{src,llh}=3^{\circ}$', color='deeppink')
plt.semilogy(sindec_30,disc_4_ss,label=r'$\sigma_{src,llh}=4^{\circ}$', color='forestgreen')
plt.semilogy(sindec_30,disc_5_ss,label=r'$\sigma_{src,llh}=5^{\circ}$', color='goldenrod')

#box = ax.get_position()
#ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5),fancybox=True, shadow=True, ncol=1, fontsize=11.5)

plt.grid(which='both')
plt.xlim(-1,1)
plt.ylim(10**(-12),3*10**(-10))
plt.legend(loc='lower left',fontsize=13.5,fancybox=True)
plt.title('Discovery Potential with signal subtraction',fontsize=18)
ax.tick_params(axis='both',which='major',length=8,labelsize=14)
ax.tick_params(axis='both',which='minor',length=4)
plt.xlabel(r'$\sin (\delta)$', fontsize=18)
plt.ylabel(r'$E^{2} dN/dE \ \  [\mathrm{TeV} \ \mathrm{cm}^{-2}\mathrm{s}^{-1}]$',fontsize=18)
fig.set_size_inches(7,4.5)
